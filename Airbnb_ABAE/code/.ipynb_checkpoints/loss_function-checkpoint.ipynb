# %%
import pandas as pd
import numpy as np
import re
from collections import defaultdict, Counter

# %%
# input_sentence

sent_dic = {}
with open('../preprocessed_data/restaurant/train.txt', 'r') as f:
    for i, sent in enumerate(f.readlines()):
        sent_dic[i] = sent.strip()

# %%
# topic_weights
tw_dic = {}
with open('../output/restaurant/topic_weights_5_arya', 'r') as f:
    for i, tw in enumerate(f.readlines()):
        tw_dic[i] = np.argmax([float(x) for x in re.findall(float_regex, tw)])

# %%
vocab = {i:{} for i in range(5)}

for ind, asp in tw_dic.items():
    sent = sent_dic[ind]
    for word in sent.split():
        if word in vocab[asp]:
            vocab[asp][word] += 1
        else:
            vocab[asp][word] = 1

# %%
sorted_vocab = {key : dict(sorted(val.items(), key = lambda x : x[1], reverse=True)) for key, val in vocab.items()}

# %%
sorted_vocab
# Out:
# {0: {'food': 164,
#   'good': 151,
#   'place': 116,
#   'like': 90,
#   'great': 86,
#   'service': 79,
#   'time': 78,
#   'one': 76,
#   'get': 74,
#   'go': 61,
#   'well': 61,
#   'really': 59,
#   'back': 53,
#   'chicken': 53,
#   'restaurant': 49,
#   'would': 46,
#   'meal': 45,
#   'also': 44,
#   'order': 42,
#   'nice': 41,
#   'ordered': 40,
#   'lunch': 40,
#   'bar': 37,
#   'salad': 36,
#   'u': 35,
#   'got': 35,
#   'come': 34,
#   'know': 33,
#   'always': 33,
#   'table': 32,
#   'little': 32,
#   'best': 32,
#   'love': 32,
#   'steak': 31,
#   'delicious': 31,
#   'try': 31,
#   'friendly': 30,
#   'price': 30,
#   'night': 30,
#   'made': 30,
#   'taco': 30,
#   'sauce': 30,
#   'first': 29,
#   'day': 29,
#   'menu': 29,
#   'dish': 29,
#   'eat': 29,
#   'drink': 29,
#   'review': 29,
#   'thing': 28,
#   'star': 28,
#   'location': 28,
#   'minute': 28,
#   'came': 27,
#   'new': 27,
#   'worth': 27,
#   'right': 27,
#   'lot': 27,
#   'could': 27,
#   'even': 27,
#   'everything': 26,
#   'make': 26,
#   'went': 26,
#   'way': 26,
#   'small': 26,
#   'definitely': 26,
#   'something': 25,
#   'two': 25,
#   'never': 25,
#   'special': 24,
#   'think': 24,
#   'amazing': 24,
#   'fry': 24,
#   'wait': 24,
#   'want': 24,
#   'bit': 23,
#   'cheese': 23,
#   'flavor': 23,
#   'dinner': 22,
#   'take': 22,
#   'server': 22,
#   'every': 22,
#   'better': 22,
#   'people': 22,
#   'beer': 22,
#   'much': 22,
#   'pretty': 21,
#   'beef': 21,
#   'side': 21,
#   'taste': 21,
#   'feel': 21,
#   'area': 21,
#   'cocktail': 21,
#   'hour': 20,
#   'going': 20,
#   'vega': 20,
#   'ok': 20,
#   'sure': 20,
#   'said': 20,
#   'experience': 20,
#   'still': 20,
#   'favorite': 19,
#   'next': 19,
#   'bad': 19,
#   'work': 19,
#   'excellent': 19,
#   'staff': 18,
#   'ever': 18,
#   'another': 18,
#   'rice': 18,
#   'year': 18,
#   'perfect': 18,
#   'portion': 18,
#   'fish': 18,
#   'fresh': 17,
#   'recommend': 17,
#   'plate': 17,
#   'atmosphere': 17,
#   'friend': 17,
#   'awesome': 17,
#   'cooked': 17,
#   'decent': 17,
#   'tasty': 16,
#   'visit': 16,
#   'super': 16,
#   'burger': 16,
#   'sweet': 16,
#   'roll': 16,
#   'bean': 16,
#   'sandwich': 16,
#   'hot': 16,
#   'water': 16,
#   'mexican': 16,
#   'many': 16,
#   'say': 16,
#   'bite': 15,
#   'potato': 15,
#   'three': 15,
#   'house': 15,
#   'last': 15,
#   'spot': 15,
#   'spicy': 15,
#   'see': 15,
#   'anything': 15,
#   'quite': 15,
#   'quality': 15,
#   'town': 15,
#   'salmon': 14,
#   'far': 14,
#   'bread': 14,
#   'egg': 14,
#   'home': 14,
#   'give': 14,
#   'big': 14,
#   'around': 14,
#   'however': 14,
#   'bartender': 14,
#   'probably': 13,
#   'husband': 13,
#   'decided': 13,
#   'else': 13,
#   'busy': 13,
#   'almost': 13,
#   'full': 13,
#   'different': 13,
#   'nothing': 13,
#   'breakfast': 13,
#   'used': 13,
#   'took': 13,
#   'asked': 13,
#   'happy': 13,
#   'away': 13,
#   'waiter': 13,
#   'course': 13,
#   'kind': 13,
#   'long': 13,
#   'quick': 12,
#   'top': 12,
#   'although': 12,
#   'slow': 12,
#   'piece': 12,
#   'onion': 12,
#   'looking': 12,
#   'green': 12,
#   'thai': 12,
#   'fried': 12,
#   'pork': 12,
#   'tried': 12,
#   'hard': 12,
#   'half': 12,
#   'found': 12,
#   'since': 12,
#   'felt': 12,
#   'look': 12,
#   'expensive': 12,
#   'thought': 12,
#   'ambiance': 12,
#   'pizza': 12,
#   'served': 12,
#   'without': 11,
#   'wine': 11,
#   'meat': 11,
#   'clean': 11,
#   'girl': 11,
#   'everyone': 11,
#   'burrito': 11,
#   'especially': 11,
#   'dessert': 11,
#   'enough': 11,
#   'tea': 11,
#   'ask': 11,
#   'find': 11,
#   'line': 11,
#   'lettuce': 11,
#   'vegetable': 11,
#   'curry': 11,
#   'chip': 11,
#   'someone': 11,
#   'eating': 11,
#   'dining': 11,
#   'open': 10,
#   'actually': 10,
#   'start': 10,
#   'coming': 10,
#   'wrong': 10,
#   'need': 10,
#   'choice': 10,
#   'cup': 10,
#   'huge': 10,
#   'wonderful': 10,
#   'red': 10,
#   'overall': 10,
#   'wish': 10,
#   'seated': 10,
#   'week': 10,
#   'party': 10,
#   '20': 10,
#   'usually': 10,
#   'point': 10,
#   'enjoyed': 10,
#   'cool': 10,
#   'old': 10,
#   'though': 10,
#   'parking': 9,
#   'cut': 9,
#   'inside': 9,
#   'bottle': 9,
#   'brought': 9,
#   'second': 9,
#   'attentive': 9,
#   'put': 9,
#   'soup': 9,
#   'told': 9,
#   'maybe': 9,
#   'done': 9,
#   'extremely': 9,
#   'outside': 9,
#   'salty': 9,
#   'real': 9,
#   'looked': 9,
#   'wife': 9,
#   'high': 9,
#   'le': 9,
#   'orange': 9,
#   'tasted': 9,
#   'butter': 9,
#   'sushi': 9,
#   'fine': 8,
#   'kid': 8,
#   'appetizer': 8,
#   'may': 8,
#   'fan': 8,
#   'either': 8,
#   'trying': 8,
#   'free': 8,
#   'mine': 8,
#   'let': 8,
#   'gave': 8,
#   'check': 8,
#   'head': 8,
#   'disappointed': 8,
#   'walk': 8,
#   'seating': 8,
#   'later': 8,
#   'mean': 8,
#   'traditional': 8,
#   'sat': 8,
#   'bowl': 8,
#   'noodle': 8,
#   'fun': 8,
#   'share': 8,
#   'flavorful': 8,
#   'authentic': 8,
#   'priced': 8,
#   'expect': 8,
#   'hash': 8,
#   'door': 8,
#   'stop': 8,
#   'money': 8,
#   'la': 8,
#   'liked': 8,
#   'cheap': 8,
#   'enjoy': 8,
#   '10': 8,
#   'cream': 8,
#   'entree': 8,
#   'waffle': 8,
#   'shrimp': 8,
#   'indian': 8,
#   'miso': 8,
#   'bacon': 8,
#   'highly': 7,
#   'decor': 7,
#   'instead': 7,
#   'japanese': 7,
#   'okay': 7,
#   'type': 7,
#   'getting': 7,
#   'extra': 7,
#   'birthday': 7,
#   'black': 7,
#   'plus': 7,
#   'kitchen': 7,
#   'return': 7,
#   'use': 7,
#   'oh': 7,
#   'whole': 7,
#   'bland': 7,
#   'part': 7,
#   'mouth': 7,
#   'list': 7,
#   'close': 7,
#   'tell': 7,
#   'spice': 7,
#   'seat': 7,
#   'kazu': 7,
#   'hungry': 7,
#   'wall': 7,
#   'waiting': 7,
#   'must': 7,
#   'miss': 7,
#   'salsa': 7,
#   'pad': 7,
#   'waitress': 7,
#   'absolutely': 7,
#   'perfectly': 7,
#   'pie': 7,
#   'manager': 7,
#   'helped': 7,
#   'perhaps': 7,
#   'overpriced': 7,
#   'size': 7,
#   'dollar': 7,
#   'bill': 7,
#   'finally': 7,
#   'fast': 7,
#   'often': 7,
#   'dressing': 7,
#   'arrived': 7,
#   'glass': 7,
#   'four': 7,
#   'hubby': 7,
#   'along': 7,
#   'typical': 7,
#   'filet': 7,
#   'item': 7,
#   'healthy': 6,
#   'family': 6,
#   'modern': 6,
#   'occasion': 6,
#   'located': 6,
#   'mind': 6,
#   'etc': 6,
#   'leave': 6,
#   'kobe': 6,
#   'joint': 6,
#   'might': 6,
#   'pancake': 6,
#   'thank': 6,
#   'music': 6,
#   'hope': 6,
#   'french': 6,
#   'style': 6,
#   'patty': 6,
#   'thinking': 6,
#   'phoenix': 6,
#   'short': 6,
#   'weekend': 6,
#   'sister': 6,
#   'hit': 6,
#   'couple': 6,
#   'chef': 6,
#   'dip': 6,
#   'selection': 6,
#   'solid': 6,
#   'hand': 6,
#   'end': 6,
#   'unfortunately': 6,
#   'creamy': 6,
#   'veggie': 6,
#   'checked': 6,
#   'feeling': 6,
#   'prepared': 6,
#   'large': 6,
#   'brown': 6,
#   'coffee': 6,
#   'sunday': 6,
#   'wrap': 6,
#   'oyster': 6,
#   'korean': 6,
#   'reason': 6,
#   'customer': 6,
#   'sorry': 6,
#   'saturday': 6,
#   'fantastic': 6,
#   'tamale': 6,
#   'ice': 6,
#   'cold': 6,
#   'others': 6,
#   'offer': 6,
#   'standard': 6,
#   'pay': 6,
#   'drive': 6,
#   'rush': 6,
#   'blue': 6,
#   'tasting': 6,
#   'main': 6,
#   'soon': 6,
#   'grilled': 6,
#   'via': 6,
#   'hooter': 6,
#   'straight': 5,
#   'level': 5,
#   'weight': 5,
#   'impressed': 5,
#   'seemed': 5,
#   'able': 5,
#   '40': 5,
#   'savory': 5,
#   'goodness': 5,
#   'glad': 5,
#   'guess': 5,
#   'specialty': 5,
#   'hostess': 5,
#   'greasy': 5,
#   'outstanding': 5,
#   'word': 5,
#   'regular': 5,
#   'boy': 5,
#   'fall': 5,
#   'due': 5,
#   'late': 5,
#   'owner': 5,
#   'tender': 5,
#   'option': 5,
#   'problem': 5,
#   'stopped': 5,
#   'cake': 5,
#   'within': 5,
#   'ago': 5,
#   'least': 5,
#   'care': 5,
#   'mom': 5,
#   'interesting': 5,
#   'thanks': 5,
#   'making': 5,
#   'bring': 5,
#   'keep': 5,
#   'street': 5,
#   'chili': 5,
#   'somewhere': 5,
#   'kinda': 5,
#   'walked': 5,
#   'establishment': 5,
#   'none': 5,
#   'medium': 5,
#   'job': 5,
#   'seen': 5,
#   'negative': 5,
#   'positive': 5,
#   'mashed': 5,
#   'white': 5,
#   'today': 5,
#   'needed': 5,
#   'presentation': 5,
#   'banana': 5,
#   'obviously': 5,
#   'loved': 5,
#   'pick': 5,
#   'hell': 5,
#   'friday': 5,
#   'combination': 5,
#   'memorable': 5,
#   'visited': 5,
#   'brunch': 5,
#   'mix': 5,
#   'mixed': 5,
#   '15': 5,
#   'ingredient': 5,
#   'low': 5,
#   'gotten': 5,
#   'called': 5,
#   'corn': 5,
#   'arizona': 5,
#   'show': 5,
#   'queso': 5,
#   'picture': 5,
#   'patio': 5,
#   'margarita': 5,
#   'asian': 5,
#   'casino': 5,
#   'lemon': 5,
#   'yet': 5,
#   'buffet': 5,
#   'cafe': 5,
#   'average': 5,
#   'anyone': 5,
#   'heard': 5,
#   'month': 5,
#   'room': 5,
#   'rather': 5,
#   'massive': 5,
#   'easy': 5,
#   'packed': 5,
#   'garlic': 5,
#   'kyara': 5,
#   'future': 4,
#   'help': 4,
#   'wagyu': 4,
#   'forward': 4,
#   'american': 4,
#   'overly': 4,
#   'true': 4,
#   'offered': 4,
#   'crazy': 4,
#   'topping': 4,
#   'western': 4,
#   'amount': 4,
#   'warm': 4,
#   'question': 4,
#   'seem': 4,
#   'soda': 4,
#   'athlete': 4,
#   'stick': 4,
#   'ground': 4,
#   'call': 4,
#   'chance': 4,
#   'waste': 4,
#   'recently': 4,
#   'guacamole': 4,
#   'concept': 4,
#   'roasted': 4,
#   'light': 4,
#   'denny': 4,
#   'per': 4,
#   'gone': 4,
#   'sized': 4,
#   'fact': 4,
#   'returned': 4,
#   'flavored': 4,
#   'puree': 4,
#   'yes': 4,
#   'downside': 4,
#   'pot': 4,
#   'chain': 4,
#   'matter': 4,
#   'game': 4,
#   'plan': 4,
#   'seeing': 4,
#   'lack': 4,
#   'eye': 4,
#   'talking': 4,
#   'multiple': 4,
#   'memory': 4,
#   'tuna': 4,
#   'seasoned': 4,
#   'flavour': 4,
#   'emerald': 4,
#   'sour': 4,
#   'entire': 4,
#   'waited': 4,
#   'world': 4,
#   'add': 4,
#   'overcooked': 4,
#   'rich': 4,
#   'across': 4,
#   'conversation': 4,
#   'boyfriend': 4,
#   'chop': 4,
#   'finish': 4,
#   'unless': 4,
#   'group': 4,
#   'ordering': 4,
#   'south': 4,
#   'bbq': 4,
#   'dry': 4,
#   'tortilla': 4,
#   'happened': 4,
#   'incredible': 4,
#   'ish': 4,
#   'lamb': 4,
#   'ate': 4,
#   'ramen': 4,
#   'italian': 4,
#   'trip': 4,
#   'writing': 4,
#   'request': 4,
#   'shake': 4,
#   'element': 4,
#   'greeted': 4,
#   'person': 4,
#   'slice': 4,
#   'wing': 4,
#   'beat': 4,
#   'based': 4,
#   'choose': 4,
#   'certainly': 4,
#   'decorated': 4,
#   'evening': 4,
#   'similar': 4,
#   'weird': 4,
#   'son': 4,
#   'thin': 4,
#   'wendy': 4,
#   'yelpers': 4,
#   'yummy': 4,
#   'fair': 4,
#   'included': 4,
#   'filling': 4,
#   'refill': 4,
#   'shop': 4,
#   'opened': 4,
#   'nicely': 4,
#   'dined': 4,
#   'excited': 4,
#   'given': 4,
#   'bunch': 4,
#   'wanted': 4,
#   'middle': 4,
#   'crisp': 4,
#   'number': 4,
#   'hero': 4,
#   'value': 4,
#   'ginger': 4,
#   'live': 4,
#   'ahi': 4,
#   'yelp': 4,
#   'smaller': 4,
#   'homemade': 4,
#   'business': 4,
#   'car': 4,
#   'jones': 4,
#   'literally': 4,
#   'buck': 4,
#   'possibly': 4,
#   'highlight': 4,
#   'hotel': 4,
#   'masala': 4,
#   'tip': 4,
#   'date': 4,
#   'reasonable': 4,
#   'tofu': 4,
#   'feijoada': 4,
#   'slightly': 4,
#   'clam': 4,
#   'filled': 4,
#   'honey': 4,
#   'mustard': 4,
#   'melted': 4,
#   'suggested': 4,
#   'chinese': 4,
#   'suggestion': 4,
#   'sit': 4,
#   'seriously': 4,
#   'health': 4,
#   'crab': 4,
#   'pittsburgh': 4,
#   'rock': 4,
#   'properly': 4,
#   'trendy': 4,
#   'thru': 4,
#   'ultra': 3,
#   'notch': 3,
#   'recent': 3,
#   'forever': 3,
#   'opted': 3,
#   'started': 3,
#   'ozs': 3,
#   'additional': 3,
#   'topped': 3,
#   'ring': 3,
#   'mall': 3,
#   'omelet': 3,
#   'describe': 3,
#   'besides': 3,
#   'wonton': 3,
#   'belong': 3,
#   'frat': 3,
#   'possible': 3,
#   'move': 3,
#   'dancing': 3,
#   'decide': 3,
#   'pro': 3,
#   'carne': 3,
#   'asada': 3,
#   'basically': 3,
#   'pulled': 3,
#   'yum': 3,
#   'country': 3,
#   'baked': 3,
#   'parked': 3,
#   'pumpkin': 3,
#   'sucked': 3,
#   'pastor': 3,
#   'fly': 3,
#   'plethora': 3,
#   'early': 3,
#   'downtown': 3,
#   'cheer': 3,
#   'st': 3,
#   'ready': 3,
#   'together': 3,
#   '24': 3,
#   'stomach': 3,
#   'known': 3,
#   'fruit': 3,
#   'cute': 3,
#   'simple': 3,
#   'anyway': 3,
#   'season': 3,
#   'office': 3,
#   'mimosa': 3,
#   'rib': 3,
#   'heavy': 3,
#   'salt': 3,
#   'meant': 3,
#   'already': 3,
#   'apps': 3,
#   'rare': 3,
#   'balanced': 3,
#   'stuff': 3,
#   '14': 3,
#   'book': 3,
#   'comfortable': 3,
#   'cabbage': 3,
#   'beet': 3,
#   'balsamic': 3,
#   'addition': 3,
#   'exactly': 3,
#   'ordinary': 3,
#   '00': 3,
#   'talk': 3,
#   'edinburgh': 3,
#   'grub': 3,
#   'bomb': 3,
#   'walking': 3,
#   'potstickers': 3,
#   'except': 3,
#   'juice': 3,
#   'believe': 3,
#   '25': 3,
#   'terrible': 3,
#   'register': 3,
#   'die': 3,
#   'case': 3,
#   'komex': 3,
#   'received': 3,
#   'fifteen': 3,
#   'name': 3,
#   'box': 3,
#   'dozen': 3,
#   'meatball': 3,
#   'pricey': 3,
#   'delight': 3,
#   'decision': 3,
#   'classic': 3,
#   'favourite': 3,
#   'sugar': 3,
#   'noticed': 3,
#   'giving': 3,
#   'rating': 3,
#   'enchilada': 3,
#   'earlier': 3,
#   'moved': 3,
#   'bone': 3,
#   'thomas': 3,
#   'spectacular': 3,
#   'beautiful': 3,
#   'cost': 3,
#   'sometimes': 3,
#   'push': 3,
#   'suck': 3,
#   'pre': 3,
#   'watch': 3,
#   'morning': 3,
#   'watcher': 3,
#   'reviewer': 3,
#   'pita': 3,
#   'grand': 3,
#   'reservation': 3,
#   'paying': 3,
#   'left': 3,
#   'hummus': 3,
#   'five': 3,
#   'bulgogi': 3,
#   'chicago': 3,
#   'setting': 3,
#   'carrot': 3,
#   'desert': 3,
#   'space': 3,
#   'dough': 3,
#   'sausage': 3,
#   'grease': 3,
#   '11': 3,
#   'loud': 3,
#   'mignon': 3,
#   'fork': 3,
#   'crispy': 3,
#   'platter': 3,
#   'fabulous': 3,
#   'view': 3,
#   'learn': 3,
#   'soggy': 3,
#   'worst': 3,
#   'crowded': 3,
#   'afraid': 3,
#   'island': 3,
#   'past': 3,
#   'hear': 3,
#   'expected': 3,
#   'scottsdale': 3,
#   'nervous': 3,
#   '5pm': 3,
#   'empty': 3,
#   'paneer': 3,
#   'normally': 3,
#   'bubble': 3,
#   'alot': 3,
#   'killer': 3,
#   'finding': 3,
#   'taro': 3,
#   'crew': 3,
#   'rate': 3,
#   'tomato': 3,
#   'samosa': 3,
#   'version': 3,
#   'otherwise': 3,
#   'run': 3,
#   'near': 3,
#   'perfection': 3,
#   'tempura': 3,
#   '44': 3,
#   'truffle': 3,
#   'spinach': 3,
#   '50': 3,
#   'sake': 3,
#   'simply': 3,
#   'noise': 3,
#   'bruschetta': 3,
#   'change': 3,
#   'skip': 3,
#   'sliced': 3,
#   'cucumber': 3,
#   'booth': 3,
#   'pleasant': 3,
#   'relaxing': 3,
#   'hidden': 3,
#   'toast': 3,
#   'tucked': 3,
#   'juicy': 3,
#   'hair': 3,
#   'mongolian': 3,
#   'event': 3,
#   'shopping': 3,
#   'fairly': 3,
#   'beverage': 3,
#   'balance': 3,
#   'relatively': 3,
#   'rude': 3,
#   'toasted': 3,
#   'answer': 3,
#   'fat': 3,
#   'personal': 3,
#   'heat': 3,
#   'tapa': 3,
#   'fav': 3,
#   'deal': 3,
#   'wrapper': 3,
#   'fusion': 3,
#   'neighborhood': 3,
#   'vida': 3,
#   'yeah': 3,
#   'bowling': 3,
#   'alley': 3,
#   'impressive': 2,
#   'wide': 2,
#   'rank': 2,
#   'among': 2,
#   'oz': 2,
#   'client': 2,
#   'cab': 2,
#   'sashimi': 2,
#   'process': 2,
#   'york': 2,
#   '100': 2,
#   'texture': 2,
#   'zucchini': 2,
#   'skinny': 2,
#   '70': 2,
#   'higher': 2,
#   'bake': 2,
#   'ham': 2,
#   'english': 2,
#   'par': 2,
#   'un': 2,
#   'mama': 2,
#   'apparently': 2,
#   'category': 2,
#   'foot': 2,
#   'break': 2,
#   'kk': 2,
#   'incredibly': 2,
#   'hang': 2,
#   'solely': 2,
#   'tag': 2,
#   'twice': 2,
#   'hated': 2,
#   'chile': 2,
#   'shot': 2,
#   'usual': 2,
#   'filiberto': 2,
#   'regardless': 2,
#   'notice': 2,
#   'completely': 2,
#   'legit': 2,
#   'college': 2,
#   'taking': 2,
#   'poutine': 2,
#   'claim': 2,
#   'gravy': 2,
#   'healthier': 2,
#   'tempe': 2,
#   'pain': 2,
#   'casual': 2,
#   'subway': 2,
#   'closest': 2,
#   'truck': 2,
#   'avoid': 2,
#   'happens': 2,
#   '80': 2,
#   'drove': 2,
#   'recommended': 2,
#   'hillside': 2,
#   'outdoor': 2,
#   'stay': 2,
#   'meeting': 2,
#   'sticker': 2,
#   'cook': 2,
#   'lastly': 2,
#   'blah': 2,
#   'shout': 2,
#   'leaf': 2,
#   'empanadas': 2,
#   'chaotic': 2,
#   'mess': 2,
#   'bigger': 2,
#   'control': 2,
#   'starting': 2,
#   'drinking': 2,
#   'izakaya': 2,
#   'guy': 2,
#   'sorta': 2,
#   'insane': 2,
#   'container': 2,
#   'squeeze': 2,
#   'extraordinary': 2,
#   'tasteless': 2,
#   'gold': 2,
#   'dear': 2,
#   'craving': 2,
#   'blond': 2,
#   'luckily': 2,
#   'corner': 2,
#   'beyond': 2,
#   'dave': 2,
#   'rubbed': 2,
#   'seasoning': 2,
#   'totally': 2,
#   'falling': 2,
#   'nonetheless': 2,
#   'delivered': 2,
#   'espresso': 2,
#   'craft': 2,
#   'key': 2,
#   'phenomenal': 2,
#   'horrible': 2,
#   'sense': 2,
#   'eager': 2,
#   'vibe': 2,
#   'bleu': 2,
#   ...},
#  1: {'food': 485,
#   'place': 420,
#   'good': 418,
#   'great': 279,
#   'service': 244,
#   'like': 243,
#   'time': 239,
#   'get': 210,
#   'one': 209,
#   'restaurant': 182,
#   'really': 179,
#   'would': 178,
#   'back': 171,
#   'go': 163,
#   'ordered': 157,
#   'chicken': 152,
#   'u': 145,
#   'menu': 142,
#   'nice': 138,
#   'also': 134,
#   'best': 125,
#   'order': 120,
#   'bar': 115,
#   'came': 113,
#   'meal': 111,
#   'come': 111,
#   'drink': 109,
#   'got': 109,
#   'well': 109,
#   'burger': 108,
#   'table': 107,
#   'delicious': 107,
#   'love': 104,
#   'first': 104,
#   'try': 103,
#   'price': 102,
#   'even': 98,
#   'experience': 98,
#   'little': 97,
#   'definitely': 97,
#   'eat': 96,
#   'went': 94,
#   'could': 87,
#   'always': 86,
#   'dish': 86,
#   'staff': 86,
#   'thing': 85,
#   'dinner': 85,
#   'friendly': 84,
#   'salad': 83,
#   'sauce': 83,
#   'pretty': 83,
#   'make': 82,
#   'lunch': 80,
#   'people': 78,
#   'much': 78,
#   'friend': 77,
#   'two': 77,
#   'never': 76,
#   'night': 75,
#   'say': 74,
#   'server': 74,
#   'ever': 73,
#   'wait': 73,
#   'better': 73,
#   'fresh': 72,
#   'happy': 71,
#   'cheese': 71,
#   'vega': 70,
#   'think': 69,
#   'taste': 69,
#   'know': 68,
#   'going': 68,
#   'hour': 68,
#   'star': 68,
#   'right': 67,
#   'waitress': 67,
#   'beer': 66,
#   'everything': 65,
#   'wine': 65,
#   'want': 64,
#   'minute': 64,
#   'day': 64,
#   'dessert': 64,
#   'give': 63,
#   'shrimp': 63,
#   'way': 62,
#   'take': 62,
#   'soup': 61,
#   'made': 61,
#   'side': 60,
#   'taco': 60,
#   'sure': 59,
#   'around': 59,
#   'said': 58,
#   'lot': 58,
#   'still': 58,
#   'since': 58,
#   'last': 57,
#   'tried': 57,
#   'though': 57,
#   'another': 57,
#   'sushi': 57,
#   'fry': 56,
#   'area': 56,
#   'large': 55,
#   'see': 55,
#   'every': 55,
#   'special': 55,
#   'flavor': 55,
#   'amazing': 54,
#   'tasty': 54,
#   'beef': 54,
#   'rice': 53,
#   'atmosphere': 52,
#   'bit': 52,
#   'many': 52,
#   'thai': 52,
#   'something': 52,
#   'hot': 51,
#   'spicy': 51,
#   'next': 51,
#   'review': 51,
#   'new': 51,
#   'perfect': 50,
#   'took': 50,
#   'egg': 49,
#   'roll': 49,
#   'told': 48,
#   'fried': 48,
#   'small': 47,
#   'worth': 47,
#   'sandwich': 47,
#   'spot': 46,
#   'enough': 46,
#   'dining': 46,
#   'portion': 46,
#   'breakfast': 46,
#   'bad': 45,
#   'feel': 45,
#   'location': 45,
#   'quality': 45,
#   'visit': 45,
#   'wanted': 45,
#   'meat': 45,
#   'different': 44,
#   'favorite': 44,
#   'family': 44,
#   'excellent': 44,
#   'ok': 44,
#   'plate': 44,
#   'look': 43,
#   'long': 43,
#   'served': 43,
#   'buffet': 43,
#   'steak': 43,
#   'cooked': 42,
#   '10': 42,
#   'house': 41,
#   'sweet': 41,
#   'big': 40,
#   'noodle': 40,
#   'choice': 40,
#   'decided': 40,
#   'super': 40,
#   'option': 40,
#   'quite': 40,
#   'awesome': 40,
#   'find': 40,
#   'wife': 39,
#   'enjoyed': 39,
#   'year': 39,
#   'usually': 39,
#   'recommend': 38,
#   'item': 38,
#   'nothing': 38,
#   'le': 38,
#   'chip': 37,
#   'party': 37,
#   'open': 37,
#   'appetizer': 36,
#   'onion': 36,
#   'mexican': 36,
#   'eating': 35,
#   'everyone': 35,
#   'bartender': 35,
#   'pork': 35,
#   'overall': 35,
#   'customer': 34,
#   'looking': 34,
#   'la': 34,
#   'actually': 34,
#   'least': 34,
#   'maybe': 34,
#   'fun': 34,
#   'kind': 34,
#   'anything': 34,
#   'finally': 34,
#   'town': 33,
#   'potato': 33,
#   'huge': 33,
#   'fast': 33,
#   'check': 33,
#   'group': 33,
#   'point': 32,
#   'green': 32,
#   'indian': 32,
#   'asked': 32,
#   'decent': 32,
#   'waiter': 32,
#   'selection': 32,
#   'second': 31,
#   'brought': 31,
#   'used': 31,
#   'full': 31,
#   'loved': 31,
#   'week': 31,
#   'half': 31,
#   'probably': 31,
#   'home': 30,
#   'bowl': 30,
#   'glass': 30,
#   'three': 30,
#   'red': 30,
#   'top': 30,
#   'let': 30,
#   'french': 30,
#   'cream': 30,
#   'need': 29,
#   'busy': 29,
#   '20': 29,
#   'husband': 29,
#   'return': 29,
#   'entree': 29,
#   'thought': 29,
#   'course': 29,
#   'attentive': 28,
#   'de': 28,
#   'instead': 28,
#   'quick': 28,
#   'style': 28,
#   'part': 28,
#   'away': 28,
#   'without': 28,
#   'outside': 28,
#   'money': 27,
#   'tea': 27,
#   'left': 27,
#   'hit': 27,
#   'put': 27,
#   'disappointed': 27,
#   'use': 27,
#   'far': 27,
#   'almost': 27,
#   'ambiance': 27,
#   'rib': 27,
#   'hard': 27,
#   'started': 27,
#   'name': 27,
#   'ask': 26,
#   'patio': 26,
#   'old': 26,
#   'especially': 26,
#   'looked': 26,
#   'couple': 26,
#   'wonderful': 26,
#   'however': 26,
#   'inside': 26,
#   'bread': 26,
#   'salmon': 26,
#   'must': 26,
#   'salsa': 26,
#   'seated': 26,
#   'extra': 25,
#   'game': 25,
#   'liked': 25,
#   'business': 25,
#   'local': 25,
#   'spice': 25,
#   'phoenix': 25,
#   'arrived': 25,
#   'found': 24,
#   'ate': 24,
#   'rather': 24,
#   'music': 24,
#   'may': 24,
#   'done': 24,
#   'pizza': 24,
#   'whole': 24,
#   'fan': 24,
#   'wish': 24,
#   'someone': 24,
#   'crowd': 24,
#   'list': 24,
#   'guy': 24,
#   'end': 24,
#   'enjoy': 24,
#   'bacon': 24,
#   'several': 24,
#   'okay': 24,
#   'seafood': 24,
#   'garlic': 24,
#   'work': 24,
#   'seemed': 24,
#   'short': 24,
#   'clean': 23,
#   'fish': 23,
#   'water': 23,
#   'coffee': 23,
#   'bean': 23,
#   'else': 23,
#   'high': 23,
#   'highly': 23,
#   'getting': 23,
#   'cold': 23,
#   'either': 23,
#   'person': 23,
#   'strip': 23,
#   'close': 23,
#   'start': 23,
#   '30': 22,
#   'sat': 22,
#   'hummus': 22,
#   'tasted': 22,
#   'drive': 22,
#   'room': 22,
#   'making': 22,
#   'care': 22,
#   'oh': 22,
#   'keep': 22,
#   'hand': 22,
#   'coming': 22,
#   'trying': 22,
#   'main': 22,
#   'door': 21,
#   'front': 21,
#   'club': 21,
#   'guess': 21,
#   'live': 21,
#   'bottle': 21,
#   'bring': 21,
#   'authentic': 21,
#   'mind': 21,
#   'expensive': 21,
#   'stuff': 21,
#   'surprised': 21,
#   'might': 21,
#   'priced': 21,
#   'remember': 21,
#   'perfectly': 20,
#   'bite': 20,
#   'cool': 20,
#   'today': 20,
#   'mean': 20,
#   'yelp': 20,
#   'although': 20,
#   'miss': 20,
#   'cocktail': 20,
#   'gave': 20,
#   'fine': 20,
#   'waiting': 20,
#   'entire': 19,
#   'manager': 19,
#   'tell': 19,
#   'lobster': 19,
#   'yet': 19,
#   'leave': 19,
#   'plus': 19,
#   'tomato': 19,
#   'amount': 19,
#   'wrong': 19,
#   'serve': 19,
#   'seating': 19,
#   'opened': 19,
#   'run': 19,
#   'stop': 19,
#   'crispy': 19,
#   'diner': 19,
#   'pepper': 19,
#   'tortilla': 19,
#   'pad': 19,
#   'wing': 19,
#   'brunch': 19,
#   'card': 19,
#   'kitchen': 19,
#   'chinese': 19,
#   'life': 18,
#   'call': 18,
#   'size': 18,
#   'girl': 18,
#   'extremely': 18,
#   'show': 18,
#   'free': 18,
#   'stopped': 18,
#   'serving': 18,
#   'pricey': 18,
#   'prepared': 18,
#   'fact': 18,
#   'seems': 18,
#   'already': 18,
#   'ice': 18,
#   'felt': 18,
#   'ended': 18,
#   'beautiful': 18,
#   'white': 18,
#   'slow': 17,
#   'walk': 17,
#   'owner': 17,
#   'korean': 17,
#   'ramen': 17,
#   'month': 17,
#   'early': 17,
#   'weekend': 17,
#   'complaint': 17,
#   'curry': 17,
#   'yum': 17,
#   'decor': 17,
#   'chef': 17,
#   'hotel': 17,
#   'split': 17,
#   'late': 17,
#   'yes': 17,
#   'toast': 17,
#   'reasonable': 17,
#   'ton': 17,
#   'yummy': 17,
#   'gone': 17,
#   'bland': 17,
#   'soon': 16,
#   'cup': 16,
#   'level': 16,
#   'easy': 16,
#   'sitting': 16,
#   'given': 16,
#   'later': 16,
#   'seriously': 16,
#   'cake': 16,
#   'waffle': 16,
#   'tasting': 16,
#   'margarita': 16,
#   'ago': 16,
#   'piece': 16,
#   'chocolate': 16,
#   'value': 16,
#   'seem': 16,
#   'type': 16,
#   'real': 16,
#   'impressed': 16,
#   'offer': 16,
#   'trip': 16,
#   'fantastic': 16,
#   'average': 16,
#   'creamy': 16,
#   '15': 16,
#   'crab': 16,
#   'idea': 15,
#   'unfortunately': 15,
#   'bill': 15,
#   'ordering': 15,
#   'lack': 15,
#   'twice': 15,
#   'pasta': 15,
#   'pot': 15,
#   'enchilada': 15,
#   '11': 15,
#   'needed': 15,
#   'set': 15,
#   'absolutely': 15,
#   'regular': 15,
#   'including': 15,
#   'grilled': 15,
#   'near': 15,
#   'parking': 15,
#   'opinion': 15,
#   'waited': 15,
#   'line': 15,
#   'loud': 15,
#   'grill': 15,
#   'treat': 15,
#   'burrito': 15,
#   'believe': 15,
#   'terrible': 15,
#   'reservation': 15,
#   'tofu': 15,
#   'employee': 15,
#   'reason': 15,
#   'buck': 15,
#   'lady': 14,
#   'quickly': 14,
#   'dry': 14,
#   '12': 14,
#   'heard': 14,
#   'saw': 14,
#   'pub': 14,
#   'nacho': 14,
#   'unique': 14,
#   'deal': 14,
#   'along': 14,
#   'expect': 14,
#   'variety': 14,
#   'brown': 14,
#   'boyfriend': 14,
#   'packed': 14,
#   'sit': 14,
#   'grab': 14,
#   'street': 14,
#   'plenty': 14,
#   'change': 14,
#   'problem': 13,
#   'pho': 13,
#   'chili': 13,
#   'bun': 13,
#   'sunday': 13,
#   'floor': 13,
#   'mentioned': 13,
#   'mushroom': 13,
#   'asian': 13,
#   'scottsdale': 13,
#   'dip': 13,
#   'tiny': 13,
#   'thru': 13,
#   'crazy': 13,
#   'recently': 13,
#   'anyway': 13,
#   'crepe': 13,
#   'past': 13,
#   'kid': 13,
#   'guest': 13,
#   'veggie': 13,
#   'expected': 13,
#   'boy': 13,
#   'pleasant': 13,
#   'flavorful': 13,
#   'rock': 13,
#   'sport': 13,
#   'worst': 13,
#   'seasoned': 13,
#   'oyster': 13,
#   'cook': 13,
#   'sometimes': 13,
#   'tuna': 13,
#   'downtown': 13,
#   'orange': 13,
#   'rest': 12,
#   'warm': 12,
#   'wall': 12,
#   'low': 12,
#   '13': 12,
#   'literally': 12,
#   'horrible': 12,
#   'concept': 12,
#   'traditional': 12,
#   'refreshing': 12,
#   'valley': 12,
#   'pancake': 12,
#   'combo': 12,
#   'hash': 12,
#   'available': 12,
#   'helpful': 12,
#   'duck': 12,
#   'recommended': 12,
#   'cheap': 12,
#   'typical': 12,
#   'paid': 12,
#   'based': 12,
#   'located': 12,
#   'stay': 12,
#   'vegetarian': 12,
#   'often': 12,
#   'lovely': 12,
#   'please': 12,
#   'total': 12,
#   'corn': 12,
#   'light': 12,
#   'slice': 12,
#   'per': 12,
#   'kept': 12,
#   'add': 12,
#   'solid': 12,
#   'overly': 12,
#   'shot': 12,
#   'outstanding': 12,
#   'fajitas': 12,
#   'standard': 12,
#   'play': 12,
#   'mention': 12,
#   'tip': 12,
#   'completely': 12,
#   'guacamole': 12,
#   'lettuce': 11,
#   'welcome': 11,
#   'affordable': 11,
#   'tender': 11,
#   'visited': 11,
#   'ball': 11,
#   'sausage': 11,
#   'homemade': 11,
#   'dressing': 11,
#   'generous': 11,
#   'able': 11,
#   'quesadilla': 11,
#   'called': 11,
#   'glad': 11,
#   'sick': 11,
#   'disappointing': 11,
#   'saturday': 11,
#   'saying': 11,
#   'butter': 11,
#   'topped': 11,
#   'four': 11,
#   'issue': 11,
#   'excited': 11,
#   'view': 11,
#   '50': 11,
#   'lamb': 11,
#   'shared': 11,
#   'question': 11,
#   'naan': 11,
#   'included': 11,
#   'craving': 11,
#   'smile': 11,
#   'texture': 11,
#   'gotten': 11,
#   'tempura': 11,
#   'die': 11,
#   'sign': 11,
#   'soft': 11,
#   'general': 11,
#   'empty': 11,
#   'five': 11,
#   'host': 11,
#   'city': 11,
#   'bbq': 11,
#   'casual': 11,
#   'behind': 10,
#   'watch': 10,
#   'note': 10,
#   'together': 10,
#   'basically': 10,
#   'space': 10,
#   'drinking': 10,
#   'cut': 10,
#   'pita': 10,
#   'picture': 10,
#   'thick': 10,
#   'vegetable': 10,
#   'mac': 10,
#   'staying': 10,
#   'pas': 10,
#   'stick': 10,
#   'matter': 10,
#   'crowded': 10,
#   'interior': 10,
#   'ceviche': 10,
#   'mix': 10,
#   'forgot': 10,
#   'cafe': 10,
#   'upon': 10,
#   'ingredient': 10,
#   'worker': 10,
#   'perhaps': 10,
#   'visiting': 10,
#   'belly': 10,
#   'sort': 10,
#   'incredible': 10,
#   'thank': 10,
#   'anyone': 10,
#   'pick': 10,
#   'grand': 10,
#   'forward': 10,
#   'offering': 10,
#   'delish': 10,
#   'sour': 10,
#   'wow': 10,
#   'frozen': 10,
#   'checked': 10,
#   'leaving': 10,
#   'mall': 10,
#   'lemon': 10,
#   'hungry': 10,
#   'dozen': 10,
#   'honestly': 10,
#   'groupon': 10,
#   'turn': 10,
#   'others': 10,
#   'taking': 10,
#   'calamari': 10,
#   'dirty': 10,
#   'pro': 10,
#   'personal': 10,
#   'understand': 10,
#   '00': 10,
#   'feeling': 10,
#   '99': 10,
#   'sorry': 10,
#   'showed': 10,
#   'pudding': 10,
#   'filled': 10,
#   'head': 10,
#   'seeing': 10,
#   'request': 9,
#   'boba': 9,
#   'north': 9,
#   'plain': 9,
#   'dollar': 9,
#   'black': 9,
#   'giving': 9,
#   'date': 9,
#   'man': 9,
#   'salt': 9,
#   'thinking': 9,
#   'worked': 9,
#   'ready': 9,
#   'dine': 9,
#   'strong': 9,
#   'pretzel': 9,
#   'spinach': 9,
#   'morning': 9,
#   'working': 9,
#   'move': 9,
#   'vibe': 9,
#   'shop': 9,
#   'etc': 9,
#   'south': 9,
#   'simple': 9,
#   'healthy': 9,
#   'cost': 9,
#   'supposed': 9,
#   'non': 9,
#   'hope': 9,
#   'offered': 9,
#   'touch': 9,
#   'impressive': 9,
#   'member': 9,
#   'share': 9,
#   'added': 9,
#   'meatball': 9,
#   'était': 9,
#   'pay': 9,
#   'true': 9,
#   'normal': 9,
#   'neighborhood': 9,
#   'face': 9,
#   'queso': 9,
#   'casino': 9,
#   'tonight': 9,
#   'received': 9,
#   'turned': 9,
#   'honey': 9,
#   'eats': 9,
#   'otherwise': 9,
#   'rate': 9,
#   'monday': 9,
#   'mother': 9,
#   'stayed': 9,
#   'terrific': 9,
#   'window': 9,
#   'mom': 9,
#   'woman': 9,
#   'coupon': 9,
#   'lacking': 9,
#   'hidden': 9,
#   'met': 9,
#   'platter': 9,
#   'positive': 9,
#   'despite': 9,
#   'establishment': 9,
#   'basil': 9,
#   'jalapeno': 9,
#   'job': 9,
#   'whatever': 9,
#   'shell': 9,
#   'began': 9,
#   'clam': 9,
#   'slider': 9,
#   'choose': 9,
#   'interesting': 9,
#   'walked': 8,
#   'spend': 8,
#   'earlier': 8,
#   'sprout': 8,
#   'stuck': 8,
#   'shredded': 8,
#   'help': 8,
#   'chose': 8,
#   'fair': 8,
#   'thanks': 8,
#   'actual': 8,
#   'somewhat': 8,
#   'world': 8,
#   'dark': 8,
#   'unless': 8,
#   'environment': 8,
#   'walking': 8,
#   'eaten': 8,
#   'kick': 8,
#   'recommendation': 8,
#   'dog': 8,
#   'owned': 8,
#   'damn': 8,
#   'generally': 8,
#   'michael': 8,
#   'pleasantly': 8,
#   'hostess': 8,
#   'charge': 8,
#   'intimate': 8,
#   'sea': 8,
#   'martini': 8,
#   'memorable': 8,
#   'rich': 8,
#   'presentation': 8,
#   'girlfriend': 8,
#   'et': 8,
#   'est': 8,
#   'frequent': 8,
#   'pleased': 8,
#   'spaghetti': 8,
#   'seat': 8,
#   'include': 8,
#   'omelette': 8,
#   'filling': 8,
#   'compared': 8,
#   'moved': 8,
#   'raw': 8,
#   'store': 8,
#   'hear': 8,
#   'major': 8,
#   'alcohol': 8,
#   'blue': 8,
#   'rush': 8,
#   'roasted': 8,
#   'ground': 8,
#   'benedict': 8,
#   'rating': 8,
#   '95': 8,
#   'mood': 8,
#   'mouth': 8,
#   'totally': 8,
#   'within': 8,
#   'filet': 8,
#   'reading': 8,
#   'japanese': 8,
#   'attitude': 8,
#   'eye': 8,
#   'surprise': 8,
#   'except': 8,
#   'incredibly': 8,
#   'buy': 8,
#   'joint': 8,
#   'noticed': 8,
#   '25': 8,
#   'talking': 8,
#   'avoid': 8,
#   'chorizo': 8,
#   'addition': 8,
#   'york': 8,
#   'coconut': 8,
#   'hair': 8,
#   'brother': 8,
#   'congee': 8,
#   'greasy': 7,
#   'immediately': 7,
#   'finished': 7,
#   'beat': 7,
#   'fat': 7,
#   'tv': 7,
#   'chance': 7,
#   'conversation': 7,
#   'fill': 7,
#   'mixed': 7,
#   'olive': 7,
#   'returned': 7,
#   'pittsburgh': 7,
#   'sad': 7,
#   'longer': 7,
#   'alone': 7,
#   'outdoor': 7,
#   'sampler': 7,
#   'combination': 7,
#   'changed': 7,
#   'disappoint': 7,
#   'professional': 7,
#   'hell': 7,
#   'lived': 7,
#   'tom': 7,
#   'avocado': 7,
#   'afternoon': 7,
#   'exactly': 7,
#   'gem': 7,
#   'bought': 7,
#   'third': 7,
#   'cute': 7,
#   'provide': 7,
#   'sell': 7,
#   'steakhouse': 7,
#   'squash': 7,
#   'bottom': 7,
#   'refill': 7,
#   'prompt': 7,
#   'truly': 7,
#   'chewy': 7,
#   'dim': 7,
#   'sum': 7,
#   'overpriced': 7,
#   'du': 7,
#   'banana': 7,
#   'certain': 7,
#   'cannot': 7,
#   'word': 7,
#   'bag': 7,
#   'meh': 7,
#   'ambience': 7,
#   'forever': 7,
#   'tap': 7,
#   'savory': 7,
#   'classic': 7,
#   'playing': 7,
#   'english': 7,
#   'spent': 7,
#   '16': 7,
#   'mistake': 7,
#   'mild': 7,
#   'shake': 7,
#   'ridiculous': 7,
#   'easily': 7,
#   'beet': 7,
#   'presented': 7,
#   'perfection': 7,
#   'par': 7,
#   'management': 7,
#   'number': 7,
#   'da': 7,
#   'apparently': 7,
#   'nearly': 7,
#   'anywhere': 7,
#   'corner': 7,
#   'center': 7,
#   'fairly': 7,
#   'range': 7,
#   'bay': 7,
#   'simply': 7,
#   'closer': 7,
#   'skewer': 7,
#   'flower': 7,
#   'stand': 7,
#   'foie': 7,
#   'limited': 7,
#   'expecting': 7,
#   'pulled': 7,
#   'bloody': 7,
#   'mary': 7,
#   'somewhere': 7,
#   'co': 7,
#   'mr': 7,
#   'weird': 7,
#   'somehow': 7,
#   'id': 7,
#   'complete': 7,
#   'taken': 7,
#   'company': 7,
#   'evening': 7,
#   'lost': 7,
#   'pan': 7,
#   'american': 7,
#   'funny': 7,
#   'poor': 7,
#   'pile': 7,
#   'notch': 7,
#   'missing': 7,
#   'birthday': 7,
#   'dumpling': 7,
#   'promptly': 7,
#   'pink': 7,
#   'pickled': 7,
#   'nicely': 7,
#   'begin': 7,
#   'enjoyable': 7,
#   'bagel': 7,
#   'topping': 7,
#   'moist': 7,
#   'chipotle': 7,
#   'friday': 6,
#   'min': 6,
#   'prefer': 6,
#   'bigger': 6,
#   'salted': 6,
#   'rare': 6,
#   'nearby': 6,
#   'doubt': 6,
#   'zucchini': 6,
#   'salty': 6,
#   'cooking': 6,
#   'bulgogi': 6,
#   'leftover': 6,
#   'satisfied': 6,
#   'read': 6,
#   'known': 6,
#   'jalapeño': 6,
#   'forget': 6,
#   'greeted': 6,
#   ...},
#  2: {'food': 337,
#   'place': 262,
#   'good': 258,
#   'great': 182,
#   'service': 167,
#   'like': 164,
#   'time': 161,
#   'get': 147,
#   'one': 145,
#   'restaurant': 118,
#   'back': 118,
#   'go': 117,
#   'u': 116,
#   'really': 112,
#   'would': 107,
#   'ordered': 102,
#   'order': 97,
#   'chicken': 93,
#   'got': 92,
#   'even': 87,
#   'came': 86,
#   'also': 86,
#   'table': 85,
#   'come': 78,
#   'dish': 77,
#   'well': 76,
#   'menu': 75,
#   'burger': 75,
#   'best': 73,
#   'love': 72,
#   'pretty': 72,
#   'try': 72,
#   'much': 68,
#   'meal': 66,
#   'nice': 65,
#   'delicious': 64,
#   'side': 63,
#   'bar': 63,
#   'drink': 62,
#   'little': 61,
#   'first': 60,
#   'thing': 60,
#   'better': 60,
#   'make': 60,
#   'star': 60,
#   'people': 59,
#   'made': 58,
#   'eat': 58,
#   'night': 57,
#   'went': 57,
#   'flavor': 56,
#   'could': 55,
#   'server': 55,
#   'friendly': 55,
#   'staff': 55,
#   'always': 54,
#   'beer': 53,
#   'definitely': 53,
#   'never': 53,
#   'sandwich': 53,
#   'price': 52,
#   'sauce': 52,
#   'experience': 51,
#   'lunch': 51,
#   'two': 51,
#   'friend': 51,
#   'think': 49,
#   'amazing': 49,
#   'know': 49,
#   'wait': 49,
#   'salad': 48,
#   'something': 47,
#   'fresh': 47,
#   'big': 47,
#   'say': 47,
#   'day': 46,
#   'sushi': 46,
#   'hour': 45,
#   'cheese': 45,
#   'going': 45,
#   'way': 44,
#   'ever': 44,
#   'small': 44,
#   'minute': 43,
#   'everything': 43,
#   'happy': 43,
#   'breakfast': 43,
#   'location': 43,
#   'bad': 43,
#   'around': 43,
#   'rice': 43,
#   'take': 42,
#   'potato': 42,
#   'vega': 42,
#   'hot': 42,
#   'give': 41,
#   'wanted': 41,
#   'said': 41,
#   'meat': 41,
#   'sure': 40,
#   'still': 40,
#   'though': 39,
#   'fried': 39,
#   'atmosphere': 39,
#   'roll': 39,
#   'next': 38,
#   'awesome': 38,
#   'husband': 38,
#   'full': 37,
#   'right': 37,
#   'fry': 37,
#   'egg': 36,
#   'special': 36,
#   'favorite': 36,
#   'beef': 36,
#   'taste': 35,
#   'ok': 35,
#   'curry': 35,
#   'tried': 35,
#   'waitress': 34,
#   'half': 34,
#   'else': 34,
#   'dinner': 34,
#   'many': 34,
#   'quite': 34,
#   'area': 34,
#   'however': 33,
#   'wine': 33,
#   'bit': 33,
#   'waiter': 32,
#   'steak': 32,
#   'taco': 32,
#   'nothing': 32,
#   'enough': 31,
#   'tasted': 31,
#   'bread': 31,
#   'tasty': 31,
#   'spot': 31,
#   'eating': 31,
#   'sweet': 31,
#   'another': 31,
#   'since': 30,
#   'asked': 30,
#   'review': 30,
#   'salsa': 30,
#   'check': 30,
#   'house': 30,
#   'chip': 30,
#   'pork': 30,
#   'year': 29,
#   'recommend': 29,
#   'bacon': 29,
#   'away': 29,
#   'new': 29,
#   'anything': 29,
#   'lot': 29,
#   'want': 28,
#   'looking': 28,
#   'course': 28,
#   'dessert': 28,
#   'worth': 28,
#   'thought': 28,
#   'seated': 28,
#   'appetizer': 28,
#   'different': 28,
#   'find': 27,
#   'choice': 27,
#   'last': 27,
#   'super': 27,
#   'served': 27,
#   'probably': 27,
#   'long': 27,
#   'took': 27,
#   'visit': 27,
#   'shrimp': 27,
#   'soup': 27,
#   'crab': 27,
#   'style': 27,
#   'maybe': 26,
#   'selection': 26,
#   'quality': 26,
#   'free': 26,
#   'burrito': 26,
#   'inside': 26,
#   'high': 26,
#   'see': 26,
#   'buffet': 26,
#   'busy': 25,
#   'ask': 25,
#   'large': 25,
#   'especially': 25,
#   'feel': 24,
#   'mexican': 24,
#   'every': 24,
#   'overall': 24,
#   'name': 24,
#   'wing': 24,
#   'decent': 24,
#   'decided': 24,
#   'le': 24,
#   'couple': 24,
#   'bring': 24,
#   'seemed': 23,
#   '10': 23,
#   'portion': 23,
#   'spicy': 23,
#   'owner': 23,
#   'put': 23,
#   'huge': 23,
#   'fan': 23,
#   'told': 23,
#   'used': 23,
#   'found': 23,
#   'light': 23,
#   'water': 23,
#   'look': 22,
#   'sat': 22,
#   'size': 22,
#   'brought': 22,
#   'wonderful': 22,
#   'dining': 22,
#   'thai': 22,
#   'option': 22,
#   'need': 22,
#   'excellent': 22,
#   'perfect': 22,
#   'trying': 22,
#   'customer': 21,
#   'wrong': 21,
#   'far': 21,
#   'kind': 21,
#   'drive': 21,
#   'grill': 21,
#   'lemon': 21,
#   'looked': 21,
#   'plate': 21,
#   'green': 21,
#   'second': 20,
#   'game': 20,
#   'yelp': 20,
#   'onion': 20,
#   '30': 20,
#   'point': 20,
#   'la': 20,
#   'tomato': 20,
#   'cool': 20,
#   'red': 20,
#   'pancake': 19,
#   'coffee': 19,
#   'started': 19,
#   'ramen': 19,
#   'town': 19,
#   'whole': 19,
#   'extra': 19,
#   'top': 19,
#   'piece': 19,
#   'bartender': 19,
#   'arrived': 19,
#   'saw': 19,
#   'work': 19,
#   'without': 19,
#   'guy': 19,
#   'let': 19,
#   'ordering': 19,
#   'list': 19,
#   'almost': 19,
#   'attentive': 18,
#   'cold': 18,
#   'three': 18,
#   '15': 18,
#   'strip': 18,
#   'cooked': 18,
#   'salmon': 18,
#   'hard': 18,
#   'left': 18,
#   'dry': 18,
#   'week': 18,
#   'might': 18,
#   'regular': 18,
#   'japanese': 18,
#   'cream': 18,
#   'ate': 17,
#   'bottle': 17,
#   'wife': 17,
#   'home': 17,
#   'return': 17,
#   'warm': 17,
#   'bite': 17,
#   'kid': 17,
#   'someone': 17,
#   'trip': 17,
#   'called': 17,
#   'noodle': 17,
#   'fantastic': 17,
#   'soon': 17,
#   'must': 17,
#   '00': 17,
#   'club': 17,
#   'tell': 17,
#   'liked': 17,
#   'everyone': 17,
#   'usually': 17,
#   'entree': 16,
#   'actually': 16,
#   'later': 16,
#   'money': 16,
#   '20': 16,
#   'enjoyed': 16,
#   'wish': 16,
#   'old': 16,
#   'least': 16,
#   'vegetable': 16,
#   'line': 16,
#   'hungry': 16,
#   'knew': 16,
#   '50': 16,
#   'getting': 16,
#   'glass': 16,
#   'walked': 16,
#   'taking': 16,
#   'bland': 16,
#   'room': 15,
#   'french': 15,
#   'cheap': 15,
#   'part': 15,
#   'pizza': 15,
#   'already': 15,
#   'hit': 15,
#   'bean': 15,
#   'juicy': 15,
#   'given': 15,
#   'music': 15,
#   'type': 15,
#   'fish': 15,
#   'cake': 15,
#   'finally': 15,
#   'veggie': 15,
#   'although': 15,
#   'others': 15,
#   'sit': 15,
#   'oh': 15,
#   'instead': 14,
#   'fast': 14,
#   'sausage': 14,
#   'ingredient': 14,
#   'white': 14,
#   'clean': 14,
#   'gave': 14,
#   'deal': 14,
#   'eaten': 14,
#   'coming': 14,
#   'group': 14,
#   'party': 14,
#   'serving': 14,
#   'black': 14,
#   'outside': 14,
#   'hope': 14,
#   'believe': 14,
#   'based': 14,
#   'waiting': 14,
#   'bbq': 14,
#   'care': 14,
#   'late': 14,
#   'garlic': 14,
#   'tip': 14,
#   'able': 14,
#   'sitting': 14,
#   'mix': 14,
#   'open': 14,
#   'butter': 14,
#   'short': 14,
#   'disappointed': 14,
#   'extremely': 13,
#   'choose': 13,
#   'reservation': 13,
#   'filling': 13,
#   'absolutely': 13,
#   'mean': 13,
#   'word': 13,
#   'local': 13,
#   'okay': 13,
#   'offer': 13,
#   'head': 13,
#   'bowl': 13,
#   'four': 13,
#   'pepper': 13,
#   'girl': 13,
#   'ice': 13,
#   'leave': 13,
#   'making': 13,
#   'stop': 13,
#   'sunday': 13,
#   'start': 13,
#   'plus': 13,
#   'may': 13,
#   'authentic': 13,
#   'several': 13,
#   'yummy': 13,
#   'greeted': 13,
#   'horrible': 13,
#   'soft': 13,
#   'medium': 13,
#   'salty': 13,
#   'cup': 12,
#   'serve': 12,
#   'cost': 12,
#   'outstanding': 12,
#   'keep': 12,
#   'fact': 12,
#   'item': 12,
#   'watch': 12,
#   'com': 12,
#   'select': 12,
#   'crispy': 12,
#   'close': 12,
#   'felt': 12,
#   'plenty': 12,
#   'quesadilla': 12,
#   'corn': 12,
#   'including': 12,
#   'seafood': 12,
#   'pay': 12,
#   'early': 12,
#   'decor': 12,
#   'grilled': 12,
#   'amount': 12,
#   'hand': 12,
#   'enjoy': 12,
#   'middle': 12,
#   'impressed': 12,
#   'seat': 12,
#   'seating': 12,
#   'spice': 12,
#   'loved': 12,
#   'scottsdale': 12,
#   'manager': 12,
#   'crowded': 11,
#   'chocolate': 11,
#   'grab': 11,
#   'fun': 11,
#   'expensive': 11,
#   'downtown': 11,
#   'use': 11,
#   'either': 11,
#   'brown': 11,
#   'quick': 11,
#   'box': 11,
#   'surprised': 11,
#   'http': 11,
#   'www': 11,
#   'biz_photos': 11,
#   'immediately': 11,
#   'waited': 11,
#   'carrot': 11,
#   'bill': 11,
#   'add': 11,
#   'yet': 11,
#   'end': 11,
#   'morning': 11,
#   'reason': 11,
#   'door': 11,
#   'expectation': 11,
#   'main': 11,
#   'guac': 11,
#   'finished': 11,
#   'mouth': 11,
#   'birthday': 11,
#   'slightly': 11,
#   'seasoned': 11,
#   'margarita': 11,
#   'yes': 11,
#   'establishment': 11,
#   'guess': 11,
#   'indian': 11,
#   'sport': 11,
#   'saturday': 11,
#   'chose': 11,
#   'tender': 11,
#   'ago': 10,
#   'along': 10,
#   'toast': 10,
#   'cocktail': 10,
#   'business': 10,
#   'unfortunately': 10,
#   'done': 10,
#   'chili': 10,
#   'poor': 10,
#   'chop': 10,
#   'buck': 10,
#   'value': 10,
#   'hostess': 10,
#   'chef': 10,
#   'seems': 10,
#   'street': 10,
#   'variety': 10,
#   'complaint': 10,
#   'mind': 10,
#   'kitchen': 10,
#   'flavorful': 10,
#   'deep': 10,
#   'live': 10,
#   'helpful': 10,
#   'lady': 10,
#   'omelet': 10,
#   'totally': 10,
#   'rare': 10,
#   'slow': 10,
#   'past': 10,
#   'share': 10,
#   'cut': 10,
#   'seem': 10,
#   'mom': 10,
#   'dog': 10,
#   'generally': 10,
#   'goat': 10,
#   'soda': 10,
#   'card': 10,
#   'tuesday': 10,
#   'calamari': 10,
#   'patio': 10,
#   'lobster': 10,
#   'needed': 10,
#   'filled': 9,
#   'ambiance': 9,
#   'considering': 9,
#   'thanks': 9,
#   'frozen': 9,
#   'simple': 9,
#   'american': 9,
#   'together': 9,
#   'total': 9,
#   '95': 9,
#   'call': 9,
#   'rest': 9,
#   'etc': 9,
#   'twice': 9,
#   'baked': 9,
#   'today': 9,
#   'whatever': 9,
#   'person': 9,
#   'tap': 9,
#   'problem': 9,
#   'space': 9,
#   'salt': 9,
#   'shop': 9,
#   'dip': 9,
#   'bun': 9,
#   'sign': 9,
#   'suggest': 9,
#   'juice': 9,
#   'joint': 9,
#   'blue': 9,
#   'bag': 9,
#   'refill': 9,
#   'walking': 9,
#   'mentioned': 9,
#   'yeah': 9,
#   'california': 9,
#   'phoenix': 9,
#   'evening': 9,
#   'tea': 9,
#   'real': 9,
#   'month': 9,
#   'boyfriend': 9,
#   'waffle': 9,
#   'ended': 9,
#   'thinking': 9,
#   'entire': 9,
#   'shredded': 9,
#   'pasta': 8,
#   'remember': 8,
#   'nut': 8,
#   'afternoon': 8,
#   'snack': 8,
#   'san': 8,
#   'missing': 8,
#   'thru': 8,
#   'parking': 8,
#   'pita': 8,
#   'cannot': 8,
#   'chinese': 8,
#   'highly': 8,
#   'seriously': 8,
#   'perfectly': 8,
#   'packed': 8,
#   'expect': 8,
#   'groupon': 8,
#   'broccoli': 8,
#   'mushroom': 8,
#   'tortilla': 8,
#   'round': 8,
#   'guacamole': 8,
#   'overcooked': 8,
#   'actual': 8,
#   'hibachi': 8,
#   'roasted': 8,
#   'turkey': 8,
#   'five': 8,
#   'chowder': 8,
#   'running': 8,
#   'asking': 8,
#   'clear': 8,
#   'upon': 8,
#   'basically': 8,
#   'shared': 8,
#   'within': 8,
#   'kinda': 8,
#   'literally': 8,
#   'wow': 8,
#   'pre': 8,
#   '45': 8,
#   'caesar': 8,
#   'kept': 8,
#   'understand': 8,
#   'help': 8,
#   'certainly': 8,
#   'expected': 8,
#   'boy': 8,
#   'diner': 8,
#   'quickly': 8,
#   'bottom': 8,
#   'omelette': 8,
#   'friday': 8,
#   'peanut': 8,
#   'hiromaru': 8,
#   'smoked': 8,
#   'banana': 8,
#   'available': 7,
#   'caramel': 7,
#   'basic': 7,
#   'prepared': 7,
#   'change': 7,
#   'life': 7,
#   'terrible': 7,
#   'presentation': 7,
#   'single': 7,
#   'front': 7,
#   'lamb': 7,
#   'tv': 7,
#   'carefree': 7,
#   '12': 7,
#   'showed': 7,
#   'paying': 7,
#   'healthy': 7,
#   'case': 7,
#   'split': 7,
#   'lettuce': 7,
#   'added': 7,
#   'counter': 7,
#   'pittsburgh': 7,
#   'opinion': 7,
#   'reasonable': 7,
#   'mayo': 7,
#   'rude': 7,
#   'guest': 7,
#   'son': 7,
#   'anyone': 7,
#   'enchilada': 7,
#   'creamy': 7,
#   'ready': 7,
#   'rich': 7,
#   'range': 7,
#   'solid': 7,
#   'thick': 7,
#   'attention': 7,
#   'face': 7,
#   'lacking': 7,
#   'fairly': 7,
#   'ball': 7,
#   'asian': 7,
#   'yum': 7,
#   'weekend': 7,
#   'crunch': 7,
#   'pro': 7,
#   'sort': 7,
#   'arizona': 7,
#   'smell': 7,
#   'pricey': 7,
#   'honey': 7,
#   'show': 7,
#   'sorry': 7,
#   'worst': 7,
#   'mild': 7,
#   'prefer': 7,
#   'pleasant': 7,
#   'management': 7,
#   'lounge': 7,
#   'chance': 7,
#   'naan': 7,
#   'none': 7,
#   'incredible': 7,
#   'across': 7,
#   'please': 7,
#   'floor': 7,
#   'rib': 7,
#   'awful': 7,
#   'lack': 7,
#   'feeling': 7,
#   'run': 7,
#   'otherwise': 7,
#   'texture': 7,
#   'greasy': 7,
#   'satisfied': 7,
#   'completely': 7,
#   'cute': 7,
#   'exactly': 7,
#   'heavy': 7,
#   'elsewhere': 7,
#   'charlotte': 7,
#   'school': 7,
#   'emeril': 7,
#   'chain': 7,
#   'hk': 7,
#   'located': 7,
#   'wth': 7,
#   'stopped': 6,
#   'moved': 6,
#   'forgot': 6,
#   'turn': 6,
#   'often': 6,
#   'besides': 6,
#   'delivered': 6,
#   'mac': 6,
#   'sometimes': 6,
#   'thank': 6,
#   'south': 6,
#   'montreal': 6,
#   'spend': 6,
#   'diego': 6,
#   'forward': 6,
#   'rush': 6,
#   'addition': 6,
#   'speak': 6,
#   'fix': 6,
#   'wearing': 6,
#   'drinking': 6,
#   'bathroom': 6,
#   'lariat': 6,
#   'ring': 6,
#   'city': 6,
#   'talk': 6,
#   'zucchini': 6,
#   'build': 6,
#   'difficult': 6,
#   'overpriced': 6,
#   'man': 6,
#   'strong': 6,
#   'crawfish': 6,
#   'plastic': 6,
#   'heat': 6,
#   'dirty': 6,
#   'standard': 6,
#   'heard': 6,
#   'neighborhood': 6,
#   'chi': 6,
#   'dollar': 6,
#   'somewhat': 6,
#   'pulled': 6,
#   'mixed': 6,
#   'fabulous': 6,
#   'original': 6,
#   'loud': 6,
#   'hang': 6,
#   'stuff': 6,
#   'movie': 6,
#   'avocado': 6,
#   'weird': 6,
#   'cook': 6,
#   'pick': 6,
#   'dark': 6,
#   'number': 6,
#   'sample': 6,
#   'attitude': 6,
#   'paid': 6,
#   'con': 6,
#   'easily': 6,
#   'waste': 6,
#   'level': 6,
#   '25': 6,
#   'ayce': 6,
#   'kobe': 6,
#   'mussel': 6,
#   'recommendation': 6,
#   'stuffed': 6,
#   'patty': 6,
#   'crust': 6,
#   'woman': 6,
#   'tonight': 6,
#   'sense': 6,
#   'overly': 6,
#   'unique': 6,
#   'plain': 6,
#   'obviously': 6,
#   'allowed': 6,
#   'combination': 6,
#   'true': 6,
#   'corner': 6,
#   'taken': 6,
#   'walk': 6,
#   'outdoor': 6,
#   'known': 6,
#   'leg': 6,
#   'pad': 6,
#   'valley': 6,
#   'smile': 6,
#   'average': 6,
#   'dressing': 6,
#   'oil': 6,
#   'salted': 6,
#   'view': 6,
#   'set': 6,
#   'mediocre': 6,
#   'giving': 6,
#   'wall': 6,
#   'working': 6,
#   'sub': 6,
#   'happened': 6,
#   'orange': 6,
#   'slice': 6,
#   'craving': 6,
#   'desert': 6,
#   'summer': 6,
#   'road': 6,
#   'container': 6,
#   'straight': 6,
#   'vegetarian': 6,
#   'beyond': 6,
#   'turned': 6,
#   'opened': 6,
#   'tonkotsu': 6,
#   'poutine': 6,
#   'tuna': 6,
#   'offered': 6,
#   'spinach': 6,
#   'chicago': 6,
#   'date': 6,
#   'barely': 6,
#   'falafel': 6,
#   'family': 5,
#   'strawberry': 5,
#   'glad': 5,
#   'cheesecake': 5,
#   'alcohol': 5,
#   'monday': 5,
#   'helped': 5,
#   'double': 5,
#   'hell': 5,
#   'quiet': 5,
#   'filet': 5,
#   'chipotle': 5,
#   'mashed': 5,
#   'hash': 5,
#   'roberto': 5,
#   'website': 5,
#   'nacho': 5,
#   'charge': 5,
#   '40': 5,
#   'talking': 5,
#   'machine': 5,
#   '11': 5,
#   'cheeseburger': 5,
#   'ahead': 5,
#   'odd': 5,
#   'fine': 5,
#   'behind': 5,
#   'folk': 5,
#   'recommended': 5,
#   'gnocchi': 5,
#   'interested': 5,
#   'wanting': 5,
#   'topped': 5,
#   'ridiculous': 5,
#   'crisp': 5,
#   'nearly': 5,
#   '99': 5,
#   'compare': 5,
#   'recently': 5,
#   'visiting': 5,
#   'car': 5,
#   'combo': 5,
#   'vibe': 5,
#   'shopping': 5,
#   'center': 5,
#   'sea': 5,
#   'bass': 5,
#   'scallion': 5,
#   'tough': 5,
#   'honestly': 5,
#   'band': 5,
#   'buddy': 5,
#   'opening': 5,
#   'requested': 5,
#   'sized': 5,
#   'throughout': 5,
#   'job': 5,
#   'future': 5,
#   'cuisine': 5,
#   'spring': 5,
#   'tofu': 5,
#   'moist': 5,
#   'lovely': 5,
#   'overwhelming': 5,
#   'homemade': 5,
#   'sent': 5,
#   'passed': 5,
#   'patron': 5,
#   'process': 5,
#   'despite': 5,
#   'stellar': 5,
#   'italian': 5,
#   'rather': 5,
#   'sake': 5,
#   'perfection': 5,
#   'soggy': 5,
#   'tiny': 5,
#   'dipping': 5,
#   'flag': 5,
#   'placed': 5,
#   'baby': 5,
#   'crazy': 5,
#   'cafe': 5,
#   'shake': 5,
#   'stayed': 5,
#   'substitution': 5,
#   'likely': 5,
#   'section': 5,
#   'expecting': 5,
#   'host': 5,
#   'beautiful': 5,
#   'named': 5,
#   'easy': 5,
#   'ton': 5,
#   'polite': 5,
#   'suggestion': 5,
#   'modern': 5,
#   'parmesan': 5,
#   'crowd': 5,
#   'promptly': 5,
#   'mall': 5,
#   'typical': 5,
#   'onto': 5,
#   'gone': 5,
#   'sum': 5,
#   'low': 5,
#   'closed': 5,
#   'min': 5,
#   'fluffy': 5,
#   'final': 5,
#   'syrup': 5,
#   'exceptional': 5,
#   'everywhere': 5,
#   'fancy': 5,
#   'employee': 5,
#   'omg': 5,
#   'coconut': 5,
#   'mango': 5,
#   'empty': 5,
#   'read': 5,
#   'meh': 5,
#   'stick': 5,
#   'delivery': 5,
#   'become': 5,
#   'uni': 5,
#   'unless': 5,
#   'deliver': 5,
#   'hearty': 5,
#   'environment': 5,
#   'traditional': 5,
#   'supper': 5,
#   'clam': 5,
#   'gem': 5,
#   'interesting': 5,
#   'state': 5,
#   'similar': 5,
#   'proof': 5,
#   'sugar': 5,
#   'video': 5,
#   'worker': 5,
#   'shot': 5,
#   'fruit': 5,
#   'hold': 4,
#   'pickle': 4,
#   'de': 4,
#   'allow': 4,
#   'truly': 4,
#   'madison': 4,
#   'japan': 4,
#   'unlike': 4,
#   'lit': 4,
#   'mignon': 4,
#   'cheddar': 4,
#   'focus': 4,
#   'fusion': 4,
#   'putting': 4,
#   'southern': 4,
#   'brunch': 4,
#   'beat': 4,
#   'satisfying': 4,
#   'due': 4,
#   'situation': 4,
#   ...},
#  3: {'food': 368,
#   'good': 286,
#   'place': 271,
#   'great': 223,
#   'like': 177,
#   'service': 161,
#   'one': 152,
#   'time': 149,
#   'go': 119,
#   'would': 111,
#   'restaurant': 109,
#   'really': 107,
#   'get': 105,
#   'ordered': 102,
#   'u': 101,
#   'order': 98,
#   'back': 96,
#   'also': 95,
#   'chicken': 94,
#   'delicious': 88,
#   'best': 87,
#   'friendly': 87,
#   'try': 82,
#   'little': 81,
#   'menu': 80,
#   'night': 80,
#   'meal': 79,
#   'always': 78,
#   'well': 78,
#   'drink': 75,
#   'come': 75,
#   'table': 75,
#   'dish': 74,
#   'price': 72,
#   'came': 70,
#   'pretty': 68,
#   'got': 68,
#   'everything': 66,
#   'amazing': 66,
#   'nice': 63,
#   'make': 63,
#   'even': 62,
#   'love': 61,
#   'first': 60,
#   'thing': 59,
#   'side': 58,
#   'two': 58,
#   'ever': 56,
#   'cheese': 56,
#   'staff': 55,
#   'sauce': 55,
#   'know': 55,
#   'definitely': 55,
#   'server': 54,
#   'made': 54,
#   'wait': 54,
#   'star': 53,
#   'right': 53,
#   'much': 53,
#   'lunch': 51,
#   'went': 51,
#   'eat': 50,
#   'experience': 50,
#   'bar': 49,
#   'friend': 49,
#   'think': 49,
#   'say': 48,
#   'fresh': 48,
#   'better': 45,
#   'burger': 45,
#   'flavor': 45,
#   'dinner': 45,
#   'day': 45,
#   'portion': 44,
#   'bit': 44,
#   'since': 43,
#   'meat': 43,
#   'minute': 42,
#   'never': 42,
#   'hour': 42,
#   'atmosphere': 41,
#   'fry': 41,
#   'taste': 41,
#   'people': 41,
#   'give': 40,
#   'roll': 40,
#   'rice': 39,
#   'salad': 39,
#   'worth': 38,
#   'awesome': 38,
#   'egg': 38,
#   'special': 38,
#   'tasty': 38,
#   'something': 37,
#   'way': 37,
#   'every': 37,
#   'going': 37,
#   'new': 37,
#   'soup': 37,
#   'happy': 37,
#   'breakfast': 36,
#   'looking': 36,
#   'served': 36,
#   'mexican': 36,
#   'chip': 36,
#   'taco': 36,
#   'want': 35,
#   'ok': 35,
#   'around': 35,
#   'though': 35,
#   'fried': 34,
#   'many': 34,
#   'plate': 34,
#   'big': 34,
#   'could': 34,
#   'excellent': 34,
#   'different': 34,
#   'sure': 34,
#   'lot': 33,
#   'tried': 33,
#   'sweet': 33,
#   'visit': 33,
#   'area': 33,
#   'still': 33,
#   'vega': 33,
#   'huge': 32,
#   'beer': 32,
#   'next': 32,
#   'hot': 31,
#   'sushi': 31,
#   'favorite': 31,
#   'nothing': 30,
#   'asked': 30,
#   'feel': 30,
#   'another': 30,
#   'probably': 29,
#   'sandwich': 29,
#   'location': 29,
#   'year': 29,
#   'top': 29,
#   'small': 28,
#   'long': 28,
#   'took': 28,
#   'take': 28,
#   'burrito': 28,
#   'waiter': 28,
#   'pork': 28,
#   'wanted': 27,
#   'quality': 27,
#   'potato': 27,
#   'waitress': 27,
#   'maybe': 27,
#   'thai': 27,
#   'ramen': 27,
#   'town': 26,
#   'owner': 26,
#   'kind': 26,
#   'husband': 26,
#   'slow': 26,
#   'see': 26,
#   'full': 25,
#   'enough': 25,
#   'beef': 25,
#   'usually': 25,
#   'busy': 25,
#   'selection': 25,
#   'recommend': 25,
#   'thought': 25,
#   'said': 25,
#   'late': 25,
#   'find': 25,
#   'cooked': 25,
# ...
#   'neither': 4,
#   'shit': 4,
#   'wasnt': 4,
#   'omg': 4,
#   'gone': 4,
#   'watching': 4,
#   'move': 4,
#   'benedict': 4,
#   'poached': 4,
#   'occasion': 4,
#   'bunch': 4,
#   'tower': 4,
#   'recently': 4,
#   'reading': 4,
#   'bag': 4,
#   'claim': 4,
#   'platter': 4,
#   'cost': 4,
#   'description': 4,
#   'covered': 4,
#   'opted': 4,
#   'whipped': 4,
#   'comment': 4,
#   'bike': 4,
#   'girl': 4,
#   'weird': 4,
#   'gotten': 4,
#   'bomb': 4,
#   'chicago': 4,
#   'private': 4,
#   'watermelon': 4,
#   'disappointing': 4,
#   'hear': 4,
#   'shell': 4,
#   'overpowering': 4,
#   'god': 4,
#   'mind': 4,
#   'sharing': 4,
#   'glad': 4,
#   'frequent': 4,
#   'reviewer': 4,
#   'experienced': 4,
#   'olive': 4,
#   'italian': 4,
#   'valley': 4,
#   'heck': 4,
#   'nicely': 4,
#   'com': 4,
#   'request': 4,
#   'puff': 4,
#   'cooky': 4,
#   'overly': 4,
#   'escargot': 4,
#   'fork': 4,
#   'machine': 4,
#   'screen': 4,
#   'boiled': 4,
#   'adult': 4,
#   'unless': 4,
#   'lesson': 4,
#   'black': 4,
#   'american': 4,
#   ...},
#  4: {'food': 350,
#   'place': 295,
#   'good': 281,
#   'great': 203,
#   'like': 169,
#   'time': 157,
#   'service': 150,
#   'get': 145,
#   'back': 137,
#   'would': 131,
#   'really': 120,
#   'one': 115,
#   'menu': 108,
#   'ordered': 102,
#   'go': 101,
#   'also': 96,
#   'restaurant': 94,
#   'come': 87,
#   'got': 86,
#   'order': 84,
#   'u': 82,
#   'cheese': 82,
#   'best': 75,
#   'drink': 74,
#   'price': 74,
#   'eat': 73,
#   'little': 73,
#   'try': 72,
#   'came': 72,
#   'chicken': 70,
#   'delicious': 70,
#   'pretty': 70,
#   'burger': 68,
#   'nice': 68,
#   'first': 68,
#   'meal': 67,
#   'dish': 66,
#   'much': 65,
#   'love': 64,
#   'even': 63,
#   'salad': 62,
#   'sauce': 62,
#   'thing': 60,
#   'definitely': 60,
#   'always': 60,
#   'bar': 59,
#   'server': 59,
#   'breakfast': 59,
#   'could': 58,
#   'better': 58,
#   'fresh': 58,
#   'people': 58,
#   'never': 57,
#   'staff': 57,
#   'way': 56,
#   'table': 56,
#   'well': 56,
#   'made': 55,
#   'experience': 55,
#   'sushi': 54,
#   'minute': 54,
#   'lunch': 54,
#   'star': 53,
#   'going': 52,
#   'know': 52,
#   'went': 51,
#   'friendly': 51,
#   'make': 51,
#   'fry': 50,
#   'beer': 50,
#   'happy': 48,
#   'said': 47,
#   'flavor': 47,
#   'still': 47,
#   'taste': 46,
#   'roll': 45,
#   'friend': 44,
#   'bit': 44,
#   'vega': 44,
#   'wait': 44,
#   'dinner': 44,
#   'say': 43,
#   'shrimp': 43,
#   'next': 43,
#   'amazing': 43,
#   'le': 43,
#   'atmosphere': 42,
#   'taco': 42,
#   'want': 41,
#   'think': 41,
#   'two': 41,
#   'ever': 41,
#   'hour': 41,
#   'egg': 41,
#   'review': 41,
#   'everything': 40,
#   'take': 40,
#   'rice': 40,
#   'sure': 40,
#   'since': 40,
#   'fried': 39,
#   'excellent': 39,
#   'right': 39,
#   'sandwich': 39,
#   'fish': 38,
#   'around': 38,
#   'many': 38,
#   'night': 37,
#   'side': 37,
#   'recommend': 37,
#   'area': 37,
#   'wine': 37,
#   'year': 36,
#   'wanted': 36,
#   'meat': 36,
#   'though': 36,
#   'give': 36,
#   'lot': 35,
#   'last': 35,
#   'coffee': 35,
#   'hot': 34,
#   'selection': 34,
#   'tasty': 34,
#   'bad': 34,
#   'day': 34,
#   'bread': 34,
#   'potato': 34,
#   'bacon': 34,
#   'long': 34,
#   'small': 34,
#   'beef': 34,
#   'cream': 34,
#   'look': 33,
#   'special': 33,
#   'sweet': 33,
#   'thought': 33,
#   'ok': 33,
#   'favorite': 32,
#   'told': 32,
#   'took': 32,
#   'spot': 32,
#   'waiter': 32,
#   'top': 32,
#   'tried': 31,
#   'something': 31,
#   'worth': 31,
#   'found': 31,
#   'another': 31,
#   'perfect': 31,
#   'asked': 31,
#   'steak': 31,
#   'three': 30,
#   'visit': 30,
#   'big': 30,
#   'dessert': 29,
#   'cooked': 29,
#   'awesome': 29,
#   'chip': 29,
#   'location': 29,
#   'every': 28,
#   'quite': 28,
#   'nothing': 28,
#   'see': 28,
#   'work': 28,
#   'plate': 27,
#   'water': 27,
#   'looking': 27,
#   'new': 27,
#   'disappointed': 27,
#   'served': 27,
#   'portion': 27,
#   'de': 27,
#   'find': 26,
#   'ask': 26,
#   'dining': 26,
#   'however': 26,
#   'home': 26,
#   'large': 26,
#   'inside': 26,
#   'chocolate': 26,
#   'maybe': 26,
#   'super': 26,
#   '15': 26,
#   'husband': 26,
#   'manager': 26,
#   'full': 25,
#   'half': 25,
#   'anything': 25,
#   'kind': 25,
#   'soup': 25,
#   'group': 25,
#   'option': 25,
#   'open': 25,
#   'regular': 25,
#   'left': 25,
#   'waitress': 25,
#   'overall': 24,
#   'must': 24,
#   'seemed': 24,
#   'instead': 24,
#   'quality': 24,
#   'loved': 24,
#   'brunch': 24,
#   'check': 24,
#   'getting': 23,
#   'oh': 23,
#   'without': 23,
#   'item': 23,
#   'enough': 23,
#   'customer': 23,
#   'pork': 23,
#   '10': 23,
#   'away': 23,
#   'huge': 23,
#   'feel': 22,
#   'different': 22,
#   'enjoy': 22,
#   'probably': 22,
#   'actually': 22,
#   'wife': 22,
#   'cold': 22,
#   'mexican': 21,
#   'old': 21,
#   'ate': 21,
#   'buffet': 21,
#   'least': 21,
#   'clean': 21,
#   'fast': 21,
#   'eating': 21,
#   'hard': 21,
#   'far': 21,
#   'bagel': 21,
#   'lobster': 21,
#   'expect': 20,
#   'chinese': 20,
#   'coming': 20,
#   'size': 20,
#   'called': 20,
#   'outside': 20,
#   'everyone': 20,
#   'looked': 20,
#   'decided': 20,
#   'else': 20,
#   'done': 20,
#   'tea': 20,
#   'green': 20,
#   'die': 20,
#   'wish': 19,
#   'red': 19,
#   'spicy': 19,
#   'piece': 19,
#   'decent': 19,
#   'put': 19,
#   'waffle': 19,
#   'cheap': 19,
#   'choice': 19,
#   'end': 19,
#   'average': 19,
#   'seated': 19,
#   'enjoyed': 19,
#   'pretzel': 19,
#   'ice': 19,
#   'la': 19,
#   'card': 19,
#   'yummy': 18,
#   'almost': 18,
#   'wing': 18,
#   'chef': 18,
#   'fan': 18,
#   'owner': 18,
#   'guy': 18,
#   'attentive': 18,
#   'hotel': 18,
#   'usually': 18,
#   'okay': 18,
#   'french': 18,
#   'need': 18,
#   'town': 18,
#   'spice': 18,
#   'onion': 18,
#   'light': 18,
#   'white': 18,
#   'thai': 18,
#   'yum': 18,
#   'plus': 18,
#   'cool': 17,
#   'course': 17,
#   'tasted': 17,
#   'later': 17,
#   'appetizer': 17,
#   'priced': 17,
#   'although': 17,
#   'started': 17,
#   'highly': 17,
#   'offer': 17,
#   'butter': 17,
#   'perfectly': 17,
#   'liked': 17,
#   'sit': 17,
#   'fantastic': 17,
#   'dip': 17,
#   'bring': 17,
#   'counter': 16,
#   'especially': 16,
#   'wonderful': 16,
#   'gave': 16,
#   'cut': 16,
#   'party': 16,
#   'impressed': 16,
#   'quick': 16,
#   'either': 16,
#   'tell': 16,
#   'fact': 16,
#   'finally': 16,
#   'brought': 16,
#   'week': 16,
#   'guess': 16,
#   'fine': 16,
#   'free': 15,
#   'close': 15,
#   'sunday': 15,
#   'family': 15,
#   'bite': 15,
#   'recommended': 15,
#   'dry': 15,
#   'mac': 15,
#   'prepared': 15,
#   'mixed': 15,
#   'pizza': 15,
#   'worst': 15,
#   'mine': 15,
#   'scallop': 15,
#   'rib': 15,
#   'tortilla': 15,
#   'mix': 15,
#   'pepper': 14,
#   'grilled': 14,
#   '20': 14,
#   'arrived': 14,
#   'part': 14,
#   'tender': 14,
#   'tomato': 14,
#   'mango': 14,
#   'salty': 14,
#   'real': 14,
#   'pancake': 14,
#   'list': 14,
#   'soft': 14,
#   'mediocre': 14,
#   'stop': 14,
#   'house': 14,
#   'flavorful': 14,
#   'walked': 14,
#   'seating': 14,
#   'trying': 14,
#   'morning': 14,
#   'stuff': 14,
#   'fun': 14,
#   'care': 14,
#   'money': 14,
#   'authentic': 14,
#   'reason': 14,
#   'curry': 14,
#   'believe': 14,
#   'est': 14,
#   'bean': 14,
#   'waiting': 14,
#   'read': 13,
#   'room': 13,
#   'couple': 13,
#   'line': 13,
#   'making': 13,
#   'man': 13,
#   'used': 13,
#   'sat': 13,
#   'waited': 13,
#   'decor': 13,
#   'may': 13,
#   'blue': 13,
#   'warm': 13,
#   'slow': 13,
#   'local': 13,
#   'variety': 13,
#   'let': 13,
#   'sorry': 13,
#   'lemon': 13,
#   'four': 13,
#   'pasta': 13,
#   'filling': 13,
#   'might': 13,
#   'someone': 13,
#   'saw': 13,
#   'use': 13,
#   'late': 13,
#   'extremely': 13,
#   'bland': 13,
#   'point': 13,
#   'yet': 13,
#   'cup': 13,
#   'mouth': 13,
#   'high': 13,
#   'trip': 12,
#   'changed': 12,
#   'salsa': 12,
#   'reasonable': 12,
#   'cook': 12,
#   'interesting': 12,
#   'phoenix': 12,
#   'pick': 12,
#   'hand': 12,
#   'choose': 12,
#   'weekend': 12,
#   'stopped': 12,
#   'amount': 12,
#   'business': 12,
#   'keep': 12,
#   'person': 12,
#   '25': 12,
#   '30': 12,
#   'salmon': 12,
#   'style': 12,
#   'wrong': 12,
#   'busy': 12,
#   'felt': 12,
#   'whole': 12,
#   'often': 12,
#   'kid': 12,
#   'entree': 12,
#   'outstanding': 12,
#   'fruit': 11,
#   'able': 11,
#   'return': 11,
#   'opened': 11,
#   'sour': 11,
#   'crab': 11,
#   'garlic': 11,
#   'tip': 11,
#   'write': 11,
#   'call': 11,
#   'traditional': 11,
#   'offered': 11,
#   'type': 11,
#   'today': 11,
#   'oyster': 11,
#   'anywhere': 11,
#   'bill': 11,
#   'date': 11,
#   'medium': 11,
#   'ambiance': 11,
#   'chewy': 11,
#   'seafood': 11,
#   'problem': 11,
#   'seem': 11,
#   'door': 11,
#   'crowd': 11,
#   'soon': 11,
#   'start': 11,
#   'already': 11,
#   'lettuce': 11,
#   'tofu': 11,
#   'rather': 11,
#   'ordering': 11,
#   'seat': 11,
#   'run': 11,
#   'mashed': 11,
#   'avocado': 11,
#   'mayo': 11,
#   'bottle': 10,
#   'five': 10,
#   'knew': 10,
#   'saturday': 10,
#   'cake': 10,
#   'total': 10,
#   'head': 10,
#   'vegetarian': 10,
#   'completely': 10,
#   'live': 10,
#   'short': 10,
#   'game': 10,
#   'boyfriend': 10,
#   'expensive': 10,
#   'street': 10,
#   'beautiful': 10,
#   '12': 10,
#   'show': 10,
#   'rare': 10,
#   'corn': 10,
#   'vegetable': 10,
#   'understand': 10,
#   'remember': 10,
#   'toast': 10,
#   'yelp': 10,
#   'bun': 10,
#   'turkey': 10,
#   'tuna': 10,
#   'extra': 10,
#   'available': 10,
#   'club': 10,
#   'working': 10,
#   'im': 10,
#   'simple': 9,
#   'within': 9,
#   'watch': 9,
#   'grand': 9,
#   'grab': 9,
#   'eye': 9,
#   'seen': 9,
#   'enchilada': 9,
#   'mushroom': 9,
#   'name': 9,
#   'sticky': 9,
#   'terrible': 9,
#   'hostess': 9,
#   'lady': 9,
#   'empty': 9,
#   'bbq': 9,
#   'burrito': 9,
#   'life': 9,
#   'serve': 9,
#   'crisp': 9,
#   'tap': 9,
#   'quickly': 9,
#   'shot': 9,
#   'based': 9,
#   'deal': 9,
#   'truffle': 9,
#   'bartender': 9,
#   'wow': 9,
#   'veggie': 9,
#   'helpful': 9,
#   'loud': 9,
#   'moved': 9,
#   'twice': 9,
#   'website': 9,
#   'chop': 9,
#   '50': 9,
#   'packed': 9,
#   'prefer': 9,
#   'paper': 9,
#   'visited': 9,
#   'thank': 9,
#   'kitchen': 9,
#   'crispy': 9,
#   'kinda': 9,
#   'cocktail': 9,
#   'expected': 9,
#   'paid': 9,
#   'beet': 9,
#   'un': 9,
#   'charge': 9,
#   'front': 9,
#   'eaten': 9,
#   'daughter': 9,
#   'booth': 9,
#   'healthy': 9,
#   'grit': 9,
#   'certain': 9,
#   'mention': 9,
#   'bathroom': 9,
#   'yes': 9,
#   'carne': 8,
#   'asada': 8,
#   'mean': 8,
#   'plenty': 8,
#   'needed': 8,
#   'valley': 8,
#   'honestly': 8,
#   'diner': 8,
#   'shared': 8,
#   'bought': 8,
#   'patio': 8,
#   'forward': 8,
#   'early': 8,
#   'except': 8,
#   'pricey': 8,
#   'somewhere': 8,
#   'located': 8,
#   'leave': 8,
#   'heard': 8,
#   'strip': 8,
#   'requested': 8,
#   'craving': 8,
#   'charlotte': 8,
#   'miss': 8,
#   'hash': 8,
#   'california': 8,
#   'noodle': 8,
#   'split': 8,
#   'pho': 8,
#   'birthday': 8,
#   'reservation': 8,
#   'unfortunately': 8,
#   'tiny': 8,
#   'melted': 8,
#   'sample': 8,
#   'others': 8,
#   'given': 8,
#   'rating': 8,
#   'avec': 8,
#   'je': 8,
#   'benedict': 8,
#   'per': 8,
#   'olive': 8,
#   'gem': 8,
#   'word': 8,
#   'brown': 8,
#   'view': 8,
#   'raw': 8,
#   'indian': 8,
#   'anyone': 8,
#   'phone': 8,
#   'exactly': 8,
#   'across': 8,
#   '00': 8,
#   'city': 8,
#   'stick': 8,
#   'spinach': 8,
#   'cilantro': 8,
#   'case': 8,
#   'app': 8,
#   'parking': 8,
#   'und': 8,
#   'seriously': 7,
#   'along': 7,
#   'change': 7,
#   'american': 7,
#   'met': 7,
#   'weird': 7,
#   'ingredient': 7,
#   'second': 7,
#   'serving': 7,
#   'desert': 7,
#   'store': 7,
#   'homemade': 7,
#   'ball': 7,
#   'slightly': 7,
#   'mentioned': 7,
#   'downtown': 7,
#   'min': 7,
#   'drive': 7,
#   'flat': 7,
#   'tough': 7,
#   'lack': 7,
#   'incredible': 7,
#   'music': 7,
#   'nut': 7,
#   'guacamole': 7,
#   'past': 7,
#   'interior': 7,
#   'greek': 7,
#   'idea': 7,
#   'standard': 7,
#   'banana': 7,
#   'black': 7,
#   'sashimi': 7,
#   'ribeye': 7,
#   'easy': 7,
#   'fix': 7,
#   'kept': 7,
#   'texture': 7,
#   'finished': 7,
#   'hungry': 7,
#   'taking': 7,
#   'honey': 7,
#   'usual': 7,
#   'salt': 7,
#   'cafe': 7,
#   'gone': 7,
#   'several': 7,
#   'ago': 7,
#   'girl': 7,
#   'casual': 7,
#   'summer': 7,
#   'saying': 7,
#   'rock': 7,
#   'hubby': 7,
#   'creamy': 7,
#   'horrible': 7,
#   'au': 7,
#   'surprise': 7,
#   'airport': 7,
#   'poutine': 7,
#   'strange': 7,
#   'italian': 7,
#   'popular': 7,
#   'sadly': 7,
#   'juicy': 7,
#   'omelet': 7,
#   'oil': 7,
#   'sea': 7,
#   'lovely': 7,
#   'delish': 7,
#   'glass': 7,
#   'quesadilla': 7,
#   'slice': 7,
#   'tv': 7,
#   'japanese': 7,
#   'forgot': 7,
#   'share': 7,
#   'complaint': 7,
#   'tail': 7,
#   'bloody': 7,
#   'mary': 7,
#   'feeling': 7,
#   'treat': 7,
#   'scone': 7,
#   'considering': 7,
#   'excited': 7,
#   'bon': 7,
#   'donut': 7,
#   'pay': 7,
#   'vig': 7,
#   'snow': 7,
#   'personally': 7,
#   'da': 7,
#   'muffin': 7,
#   'ai': 7,
#   'pleasant': 7,
#   'stomach': 6,
#   'grill': 6,
#   'note': 6,
#   'finish': 6,
#   'peanut': 6,
#   'fair': 6,
#   'asking': 6,
#   'help': 6,
#   'received': 6,
#   'typical': 6,
#   'hummus': 6,
#   'cost': 6,
#   'beat': 6,
#   'partner': 6,
#   'asian': 6,
#   'berry': 6,
#   'included': 6,
#   'plan': 6,
#   'biscuit': 6,
#   'gravy': 6,
#   'impressive': 6,
#   'combination': 6,
#   'delivery': 6,
#   'combo': 6,
#   'margarita': 6,
#   'joe': 6,
#   'apparently': 6,
#   'spend': 6,
#   'etc': 6,
#   'pastry': 6,
#   'literally': 6,
#   'clam': 6,
#   'walk': 6,
#   'mind': 6,
#   'wrapped': 6,
#   'fabulous': 6,
#   'set': 6,
#   'phenomenal': 6,
#   'flight': 6,
#   'smoked': 6,
#   'rude': 6,
#   'rest': 6,
#   'please': 6,
#   'baby': 6,
#   'blah': 6,
#   'matter': 6,
#   'worker': 6,
#   'sad': 6,
#   'space': 6,
#   'cash': 6,
#   'forever': 6,
#   'gras': 6,
#   'duck': 6,
#   'wall': 6,
#   'month': 6,
#   'seems': 6,
#   'beverage': 6,
#   'starter': 6,
#   'entire': 6,
#   'shake': 6,
#   'stuck': 6,
#   'basically': 6,
#   'yellow': 6,
#   'pa': 6,
#   'non': 6,
#   'montreal': 6,
#   'putting': 6,
#   'double': 6,
#   'notch': 6,
#   'jam': 6,
#   'iced': 6,
#   '99': 6,
#   'dont': 6,
#   'stuffed': 6,
#   'value': 6,
#   'korean': 6,
#   'neighborhood': 6,
#   'hit': 6,
#   'self': 6,
#   'bowl': 6,
#   'smile': 6,
#   'clearly': 6,
#   'presentation': 6,
#   'thin': 6,
#   'hope': 6,
#   'ayce': 6,
#   'none': 6,
#   'window': 6,
#   'bother': 6,
#   'roasted': 6,
#   'sport': 6,
#   'cozy': 6,
#   'sitting': 6,
#   'belly': 6,
#   'pot': 6,
#   'beyond': 6,
#   'et': 6,
#   'si': 6,
#   'baked': 6,
#   'simply': 6,
#   'bf': 6,
#   'bang': 6,
#   'ketchup': 6,
#   'von': 6,
#   'sich': 6,
#   'chile': 6,
#   'pour': 6,
#   'filled': 6,
#   'lux': 6,
#   'paul': 6,
#   'lon': 6,
#   'crepe': 6,
#   'affordable': 5,
#   'cannot': 5,
#   'honest': 5,
#   'sign': 5,
#   'kung': 5,
#   'yelpers': 5,
#   'happened': 5,
#   'unless': 5,
#   'soda': 5,
#   'afternoon': 5,
#   'mostly': 5,
#   'gyro': 5,
#   'fire': 5,
#   'immediately': 5,
#   'pita': 5,
#   'fluffy': 5,
#   'box': 5,
#   'round': 5,
#   'cheddar': 5,
#   'known': 5,
#   'disappointing': 5,
#   'ambience': 5,
#   'draft': 5,
#   'ring': 5,
#   'buffalo': 5,
#   'cinnamon': 5,
#   'unique': 5,
#   'easily': 5,
#   'platter': 5,
#   'spring': 5,
#   'supposed': 5,
#   'tasting': 5,
#   'football': 5,
#   'fairly': 5,
#   'calamari': 5,
#   'lamb': 5,
#   'nan': 5,
#   'chipotle': 5,
#   'bomb': 5,
#   'crazy': 5,
#   'famous': 5,
#   'thick': 5,
#   'glad': 5,
#   'solid': 5,
#   'age': 5,
#   'showed': 5,
#   'heavy': 5,
#   'hopefully': 5,
#   'mood': 5,
#   'spent': 5,
#   'reading': 5,
#   'page': 5,
#   'absolutely': 5,
#   'balance': 5,
#   'seasoning': 5,
#   'added': 5,
#   'southern': 5,
#   'squid': 5,
#   'cuban': 5,
#   'co': 5,
#   'hang': 5,
#   'pie': 5,
#   '95': 5,
#   'checked': 5,
#   'suggestion': 5,
#   'lower': 5,
#   'edge': 5,
#   'recently': 5,
#   'main': 5,
#   'foie': 5,
#   'joint': 5,
#   'complain': 5,
#   'hold': 5,
#   'filet': 5,
#   'pudding': 5,
#   'perfection': 5,
#   'orange': 5,
#   'evening': 5,
#   'station': 5,
#   'shop': 5,
#   'jalapeno': 5,
#   'salted': 5,
#   'dipping': 5,
#   'overpriced': 5,
#   'très': 5,
#   'ce': 5,
#   'une': 5,
#   'banquet': 5,
#   'busser': 5,
#   'attention': 5,
#   'chicago': 5,
#   'otherwise': 5,
#   'experienced': 5,
#   'imagine': 5,
#   'chandler': 5,
#   'everywhere': 5,
#   'reasonably': 5,
#   'sake': 5,
#   'ceiling': 5,
#   'topped': 5,
#   'risotto': 5,
#   'happens': 5,
#   'juice': 5,
#   '11': 5,
#   'cheaper': 5,
#   'hear': 5,
#   'polite': 5,
#   'professional': 5,
#   'cheesy': 5,
#   'vanilla': 5,
#   'vibe': 5,
#   'certainly': 5,
#   'highlight': 5,
#   'truck': 5,
#   'girlfriend': 5,
#   'lemonade': 5,
#   'personal': 5,
#   'somewhat': 5,
#   'establishment': 5,
#   'dirty': 5,
#   'totally': 5,
#   'modern': 5,
#   'dollar': 5,
#   'martini': 5,
#   '100': 5,
#   'bottom': 5,
#   'pleased': 5,
#   'chili': 5,
#   'guest': 5,
#   'hipster': 5,
#   'play': 5,
#   'perhaps': 5,
#   'turned': 5,
#   'visiting': 5,
#   'figured': 5,
#   'rabbit': 5,
#   'ground': 5,
#   '11pm': 5,
#   'goodness': 5,
#   'welcoming': 5,
#   'fit': 5,
#   'building': 5,
#   'mr': 5,
#   '80': 5,
#   'previous': 5,
#   'thinking': 5,
#   'nicht': 5,
#   'das': 5,
#   'pleasantly': 5,
#   'surprised': 5,
#   'dim': 5,
#   'sum': 5,
#   'organic': 5,
#   'placed': 5,
#   'quail': 5,
#   'properly': 5,
#   'drinking': 5,
#   'palazzo': 5,
#   'watermelon': 5,
#   'tenderloin': 5,
#   'walking': 4,
#   'stand': 4,
#   'obviously': 4,
#   'wtf': 4,
#   'pao': 4,
#   'damn': 4,
#   'fellow': 4,
#   'expecting': 4,
#   'dead': 4,
#   'baklava': 4,
#   ...}}

# %%
sum(sorted_vocab.get(0).values())
# Out:
# 11174

# %%
# Indicative

indicative_dic = {}
for i in range(5):
    A_j = sum(sorted_vocab.get(i).values())
    A_j_w = np.fromiter(sorted_vocab.get(i).values(), dtype=float)
    indicative_dic[i] = A_j_w / A_j

# %%
indicative_dic
# Out:
# {0: array([1.46769286e-02, 1.35135135e-02, 1.03812422e-02, ...,
#         8.94934670e-05, 8.94934670e-05, 8.94934670e-05]),
#  1: array([1.39379832e-02, 1.20700060e-02, 1.20125298e-02, ...,
#         2.87381096e-05, 2.87381096e-05, 2.87381096e-05]),
#  2: array([1.42730083e-02, 1.10965228e-02, 1.09271102e-02, ...,
#         4.23531405e-05, 4.23531405e-05, 4.23531405e-05]),
#  3: array([1.64704829e-02, 1.28004297e-02, 1.21290785e-02, ...,
#         4.47567471e-05, 4.47567471e-05, 4.47567471e-05]),
#  4: array([1.45997581e-02, 1.23055104e-02, 1.17215200e-02, ...,
#         4.17135945e-05, 4.17135945e-05, 4.17135945e-05])}

# %%
# Distinctive
distinctive_dic = {}
for i in range(5):
    A_k_w_sub = []
    for w, f in sorted_vocab.get(i).items():
        A_j_w = f
        for j in range(5):
            try:
                A_k_w = sorted_vocab.get(j)[w]
            except:
                A_k_w = 0
            A_k_w_sub.append(A_k_w)
    distinctive_dic[i][w] = A_j_w / max(A_k_w_sub)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-351-fa5e7f45998c> in <module>
#      11                 A_k_w = 0
#      12             A_k_w_sub.append(A_k_w)
# ---> 13     distinctive_dic[i][w] = A_j_w / max(A_k_w_sub)
#
# KeyError: 0

# %%
w
# Out:
# 'goldfingers'
