# %%
import gc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_listings = pd.read_csv('../datasets/listings.csv', low_memory=False)

# %%
aspect_listings = pd.read_csv('../output/newyork/aspect_listings.csv')

# %%
raw_listings.columns.to_list()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
item_listings = raw_listings[['host_id',
                              'host_is_superhost',
                              'host_listings_count', 
                              'host_total_listings_count', 
                              'number_of_reviews', 
                              'number_of_reviews_ltm', 
                              'review_scores_rating']]

# %%
item_listings[item_listings['host_is_superhost']=='t']
# Out:
#          host_id host_is_superhost  host_listings_count  \
# 7           7549                 t                  4.0
# 8           7989                 t                  1.0
# 10          9744                 t                  3.0
# 14         16800                 t                  3.0
# 15         17571                 t                  1.0
# ...          ...               ...                  ...
# 50162  103556381                 t                  0.0
# 50180    4964682                 t                  2.0
# 50196  305666992                 t                  1.0
# 50227   23003173                 t                  0.0
# 50236   48054322                 t                  1.0
#
#        host_total_listings_count  number_of_reviews  number_of_reviews_ltm  \
# 7                            4.0                161                      3
# 8                            1.0                213                     32
# ...

# %%
g_1 = pd.merge(aspect_listings, item_listings, on='host_id')

# %%
g_1.groupby('host_is_superhost')['topic_5'].value_counts()
# Out:
# host_is_superhost  topic_5
# f                  4          18329
#                    0          15725
#                    3          12132
#                    2          12091
#                    1          10240
# t                  4           8217
#                    0           5201
#                    3           4605
#                    2           3937
#                    1           3746
# Name: topic_5, dtype: int64

# %%
g_1.groupby('host_is_superhost')['topic_5'].value_counts()['t'].sort_index()
# Out:
# topic_5
# 0    5201
# 1    3746
# 2    3937
# 3    4605
# 4    8217
# Name: topic_5, dtype: int64

# %%
# super host = 'false', proposition of aspects
f, ax = plt.subplots(1, 2, figsize=(15,15))

ax[0].pie(g_1.groupby('host_is_superhost')['topic_5'].value_counts()['f'].sort_index(), 
                labels=[0,1,2,3,4], autopct='%1.2f%%', shadow=True)
ax[1].pie(g_1.groupby('host_is_superhost')['topic_5'].value_counts()['t'].sort_index(), 
                labels=[0,1,2,3,4], autopct='%1.2f%%', shadow=True)
ax[0].title.set_text('Superhost=False')
ax[1].title.set_text('Superhost=True')
plt.show()

# %%
g_1.groupby('topic_5')['review_scores_rating'].mean()
# Out:
# topic_5
# 0    93.423566
# 1    94.869648
# 2    94.822567
# 3    94.917890
# 4    94.437454
# Name: review_scores_rating, dtype: float64

# %%
g_1.groupby('topic_5')['number_of_reviews'].mean()
# Out:
# topic_5
# 0    30.676001
# 1    34.815816
# 2    32.586723
# 3    36.702276
# 4    38.183568
# Name: number_of_reviews, dtype: float64

# %%
g_1.groupby('topic_5')['host_total_listings_count'].mean()
# Out:
# topic_5
# 0    86.531014
# 1    46.662949
# 2     5.442975
# 3     2.250702
# 4    68.089882
# Name: host_total_listings_count, dtype: float64

# %%
tmp = aspect_listings.pivot_table(index='host_id', columns='topic_5', aggfunc='size', fill_value=0).reset_index()
tmp.columns = ['host_id','a_0', 'a_1','a_2','a_3','a_4']

# %%
g_2 = pd.merge(item_listings, tmp, on='host_id')

# %%
g_2
# Out:
#          host_id  host_listings_count  host_total_listings_count  \
# 0           2845                  6.0                        6.0
# 1           2845                  6.0                        6.0
# 2           4869                  1.0                        1.0
# 3           7322                  1.0                        1.0
# 4           7356                  1.0                        1.0
# ...          ...                  ...                        ...
# 28471   23003173                  0.0                        0.0
# 28472  345447741                  0.0                        0.0
# 28473  253612429                  0.0                        0.0
# 28474  283589680                  0.0                        0.0
# 28475  246410337                  0.0                        0.0
#
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  a_0  \
# 0                     48                      4                  94.0    0
# ...
