# %%
import pandas as pd

# %%
data = pd.read_csv('new_reviews.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#        Unnamed: 0 listing_id            id        date  reviewer_id  \
# 0               0       3781  3.777682e+07  2015-07-10   36059247.0
# 1               1       3781  4.184249e+07  2015-08-09   10459388.0
# 2               2       3781  4.528215e+07  2015-09-01   12264652.0
# 3               3       3781  4.902265e+07  2015-09-30   41426327.0
# 4               4       3781  5.250333e+07  2015-10-30   15151513.0
# ...           ...        ...           ...         ...          ...
# 129545     128306   53631121  5.144466e+17  2021-12-10  395793616.0
# 129546     128307   53631585  5.166418e+17  2021-12-13   53102978.0
# 129547     128308   53704154  5.158749e+17  2021-12-12  409683314.0
# 129548     128309   53719658  5.165859e+17  2021-12-13  241067792.0
# 129549     128310   53719658  5.188594e+17  2021-12-16    1386178.0
#
#        reviewer_name                                           comments  \
# 0               Greg  The apartment was as advertised and Frank was ...
# ...

# %%
with open('train_.txt', 'w', encoding='UTF-8') as f:
    for i in data['comments']:
        f.write(i+"\n")
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-6-b1225bb41aec> in <module>
#       1 with open('train_.txt', 'w', encoding='UTF-8') as f:
#       2     for i in data['comments']:
# ----> 3         f.write(i+"\n")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
