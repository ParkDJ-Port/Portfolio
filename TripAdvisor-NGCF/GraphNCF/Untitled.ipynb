# %%
import pandas as pd

# %%
rt = pd.read_csv('ffff.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
rt
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 32771       44657         49990
# 32772       44658         49992
# 32773       44659         49993
# 32774       44660         49994
# 32775       44662         49996
#
#                                                        0  rating  \
# 0      {"ratings": {"service": 5.0 "cleanliness": 5.0...       5
# 1      {"ratings": {"service": 5.0 "cleanliness": 5.0...       5
# 2      {"ratings": {"service": 4.0 "cleanliness": 5.0...       4
# 3      {"ratings": {"service": 5.0 "cleanliness": 5.0...       4
# 4      {"ratings": {"service": 4.0 "cleanliness": 5.0...       4
# ...                                                  ...     ...
# 32771  {"ratings": {"service": 3.0, "cleanliness": 3....       4
# ...

# %%
userNum = rt['user_id'].nunique()
itemNum = rt['list_id'].nunique()

# %%
userNum
# Out:
# 30949

# %%
lst_item_id = rt['list_id'].to_list()

# %%
lst_item_id = list(set(lst_item_id))

# %%
lst_user_id = rt['user_id'].to_list()

# %%
lst_user_id = list(set(lst_user_id))

# %%
dic = {}

# %%
for ind,value in enumerate(lst_item_id):
    dic[f'{value}'] = ind

# %%
dic['93338']
# Out:
# 245

# %%
type(rt['list_id'][0])
# Out:
# numpy.int64

# %%
rt['list_id'] = rt['list_id'].apply(lambda x: str(x))

# %%
rt['item_id']=0
for ind in range(len(rt)):
    rt['item_id'][ind]=dic[rt['list_id'][ind]]
# Out:
# <ipython-input-37-fe7a6b09e022>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rt['item_id'][ind]=dic[rt['list_id'][ind]]

# %%
rt['user_id'].nunique(), rt['user_id'].max()
# Out:
# (38739, 38738)

# %%
rt.to_csv('eeee.csv')

# %%
dic
# Out:
# {'651265': 0,
#  '247814': 1,
#  '124937': 2,
#  '530458': 3,
#  '596013': 4,
#  '596014': 5,
#  '1212489': 6,
#  '282699': 7,
#  '266326': 8,
#  '254040': 9,
#  '645215': 10,
#  '1007724': 11,
#  '1026192': 12,
#  '608401': 13,
#  '1155229': 14,
#  '290978': 15,
#  '290982': 16,
#  '290987': 17,
#  '1218737': 18,
#  '1237172': 19,
#  '641209': 20,
#  '3502291': 21,
#  '665814': 22,
#  '1990870': 23,
#  '2531544': 24,
#  '239836': 25,
#  '518371': 26,
#  '284904': 27,
#  '80107': 28,
#  '239853': 29,
#  '80112': 30,
#  '239857': 31,
#  '239858': 32,
#  '239859': 33,
#  '239865': 34,
#  '641273': 35,
#  '286987': 36,
#  '286988': 37,
#  '1966350': 38,
#  '1456411': 39,
#  '1575212': 40,
#  '260396': 41,
#  '559409': 42,
#  '1556786': 43,
#  '1155392': 44,
#  '254281': 45,
#  '125274': 46,
#  '651629': 47,
#  '3393901': 48,
#  '293234': 49,
#  '1630591': 50,
#  '559491': 51,
#  '1577352': 52,
#  '622987': 53,
#  '223146': 54,
#  '1642905': 55,
#  '815515': 56,
#  '1456560': 57,
# ...

# %%
dic
# Out:
# {'275350DA8CBE93F172EFED3EA9FF5914': 0,
#  '9E6D1593A6D3BB8644A98EFE7446CE3B': 1,
#  '7214EF4B855B3497765C2699B1478B1D': 2,
#  'AB860DA1F677F5A0639B291C1F2B151C': 3,
#  '822D9AB96809F95F312BDD0BF7A965AE': 4,
#  'C512A93C84E0E8797D5987D7404E480F': 5,
#  '9D1814FA452C841A3EB79FA7797A3B12': 6,
#  '035388FAF715546D22796D5BB21B87E6': 7,
#  'A54CB0A669574C228DD20F0823BA9E1F': 8,
#  'A0F826AA873A09F87814C1C44AC409D5': 9,
#  'DA7C347D0F240CC29916FBB7D9B842DC': 10,
#  '49DAD85127F7AC66938FBBAB80F2EE27': 11,
#  'D8D6BCE37096BEB06F3BC6B21FDCA531': 12,
#  '38EC43AB6AA36660207B0CB6B0262AA9': 13,
#  '27D0ACE4A62C87ACD42F3AF39593C0D9': 14,
#  '21BCCB69AED7156009B1580F871D1582': 15,
#  '41C2B31D48A48F71FE23FE05B5553561': 16,
#  '020A83B2BF1A2AF7F58057BC10BB129B': 17,
#  'D874C6363EE68A0F560B8439D7AA5039': 18,
#  'F790E7DE01D1B1C0D6839856FA83C134': 19,
#  'B0E2B5A6BD762BCD89834DAB8139073F': 20,
#  'D392137464E690694656D2E59914B25B': 21,
#  'F55024E5BC6207F472297B9242BDA715': 22,
# ...

# %%
for ind in lst_reviewer_id[:3]:
    print(rt[rt['reviewer_id'] == f'{ind}'].index
# Out:
# Int64Index([28359], dtype='int64')
# Int64Index([30485], dtype='int64')
# Int64Index([25972], dtype='int64')

# %%
itemNum
# Out:
# 498

# %%
rt['reviewer_id'] = rt['reviewer_id'] - 1
rt['listing_id'] = rt['listing_id'] - 1
# Out:
# TypeErrorTraceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68     with np.errstate(all="ignore"):
# ...
